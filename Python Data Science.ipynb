# %% [markdown]
# # Python Practice
# #### Started on June 1, 2019
# ---

# %% [markdown]
# ## 1. Basics
# ### Commands

# %%
# !pwd
# Out:
# /Users/Nima/Python Training

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autocall  %automagic  %autosave  %bookmark  %cat  %cd  %clear  %colors  %config  %connect_info  %cp  %debug  %dhist  %dirs  %doctest_mode  %ed  %edit  %env  %gui  %hist  %history  %install_default_config  %install_ext  %install_profiles  %killbgscripts  %ldir  %less  %lf  %lk  %ll  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %lx  %macro  %magic  %man  %matplotlib  %mkdir  %more  %mv  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %popd  %pprint  %precision  %profile  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %rep  %rerun  %reset  %reset_selective  %rm  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# ...

# %% [markdown]
# ### Operators and Basic Data Types

# %%
5*3**2%14
# Out:
# 3

# %%
5/8
# Out:
# 0

# %%
5.0/8
# Out:
# 0.625

# %%
savings = 100
print(savings)
# Out:
# 100

# %%
Profitable = True
textstr = 'Hello'
print(type(Profitable))
print(type(textstr))
# Out:
# <type 'bool'>
# <type 'str'>

# %%
type(Profitable)
# Out:
# bool

# %%
type(textstr)
# Out:
# str

# %%
desc = "compound interest"
desc+desc
# Out:
# 'compound interestcompound interest'

# %%
print("I started with $" + str(savings) + " and now have $" + str(savings*1.1**7) + ". Awesome!")
# Out:
# I started with $100 and now have $194.87171. Awesome!

# %%
bool(5)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(0.0)
# Out:
# False

# %%
bool(-1)
# Out:
# True

# %%
bool('a')
# Out:
# True

# %%
bool('0')
# Out:
# True

# %%
bool(5-5)
# Out:
# False

# %%
bool(False)
# Out:
# False

# %%
"I can add integers, like " + str(5) + " to strings."
# Out:
# 'I can add integers, like 5 to strings.'

# %%
"I said " + ("Hey " * 2) + "Hey!"
# Out:
# 'I said Hey Hey Hey!'

# %%
True + False
# Out:
# 1

# %%
type(True + False)
# Out:
# int

# %%
True * False
# Out:
# 0

# %%
True ** False
# Out:
# 1

# %%
type(True * False)
# Out:
# int

# %%
1 * False
# Out:
# 0

# %%
bool(True + False)
# Out:
# True

# %%
bool(1 * False)
# Out:
# False

# %%
bool(True * 0)
# Out:
# False

# %%
True & False
# Out:
# False

# %%
True | False
# Out:
# True

# %%
~ True
# Out:
# -2

# %%
~ False
# Out:
# -1

# %%
True and False
# Out:
# False

# %%
True or False
# Out:
# True

# %%
not True
# Out:
# False

# %%
True == True
# Out:
# True

# %%
True != False
# Out:
# True

# %%
1 != True
# Out:
# False

# %%
1 == True
# Out:
# True

# %%
~ 5
# Out:
# -6

# %%
~ -5
# Out:
# 4

# %% [markdown]
# ### Lists

# %%
# area variables (in square meters)
hall = 11.25
kit = 18.0
liv = 20.0
bed = 10.75
bath = 9.50

# Create list areas
areas = [hall, kit, liv, bed, bath]

# Print areas
print(areas)
# Out:
# [11.25, 18.0, 20.0, 10.75, 9.5]

# %%
type(areas)
# Out:
# list

# %%
print(type(areas))
# Out:
# <type 'list'>

# %%
areas = ["hallway", hall, "kitchen", kit, "living room", liv, "bedroom", bed, "bathroom", bath]
print(areas)
# Out:
# ['hallway', 11.25, 'kitchen', 18.0, 'living room', 20.0, 'bedroom', 10.75, 'bathroom', 9.5]

# %%
areas = [["hallway", hall], ["kitchen", kit], ["living room", liv], ["bedroom", bed], ["bathroom", bath]]
print(areas)
# Out:
# [['hallway', 11.25], ['kitchen', 18.0], ['living room', 20.0], ['bedroom', 10.75], ['bathroom', 9.5]]

# %%
type(areas)
# Out:
# list

# %%
[1 + 2, "a" * 5, 3]
# Out:
# [3, 'aaaaa', 3]

# %% [markdown]
# #### Subsetting

# %%
areas = ["hallway", 11.25, "kitchen", 18.0, "living room", 20.0, "bedroom", 10.75, "bathroom", 9.50]
areas[1]
# Out:
# 11.25

# %%
areas[-1]
# Out:
# 9.5

# %% [markdown]
# _** Note:** backward index = forward index - length_

# %% [markdown]
# #### Slicing

# %%
areas[1:5]
# Out:
# [11.25, 'kitchen', 18.0, 'living room']

# %% [markdown]
# _** Note: ** [start inclusive : end exclusive]_

# %%
areas[:5]
# Out:
# ['hallway', 11.25, 'kitchen', 18.0, 'living room']

# %%
areas[1:1]
# Out:
# []

# %%
areas[:]
# Out:
# ['hallway',
#  11.25,
#  'kitchen',
#  18.0,
#  'living room',
#  20.0,
#  'bedroom',
#  10.75,
#  'bathroom',
#  9.5]

# %%
areas[5:]
# Out:
# [20.0, 'bedroom', 10.75, 'bathroom', 9.5]

# %%
areas[-1:-5]
# Out:
# []

# %%
areas[-5:-1]
# Out:
# [20.0, 'bedroom', 10.75, 'bathroom']

# %%
areas[-1:-1]
# Out:
# []

# %%
areas[-5:2]
# Out:
# []

# %%
areas = [["hallway", hall], ["kitchen", kit], ["living room", liv], ["bedroom", bed], ["bathroom", bath]]
areas[1][1] # select kit
# Out:
# 18.0

# %%
areas[-1][0]
# Out:
# 'bathroom'

# %% [markdown]
# #### List Manipulations: Change, Add, Remove, Copy

# %%
areas = ["hallway", 11.25, "kitchen", 18.0, "living room", 20.0, "bedroom", 10.75, "bathroom", 9.50]

# %%
areas[-1]=10.5
areas
# Out:
# ['hallway',
#  11.25,
#  'kitchen',
#  18.0,
#  'living room',
#  20.0,
#  'bedroom',
#  10.75,
#  'bathroom',
#  10.5]

# %%
areas_1 = areas + ["poolhouse", 24.5]
areas_1
# Out:
# ['hallway',
#  11.25,
#  'kitchen',
#  18.0,
#  'living room',
#  20.0,
#  'bedroom',
#  10.75,
#  'bathroom',
#  10.5,
#  'poolhouse',
#  24.5]

# %%
del(areas[-4:-2])
areas
# Out:
# ['hallway', 11.25, 'kitchen', 18.0, 'living room', 20.0, 'bathroom', 10.5]

# %%
areas_2 = areas[:]
areas_2 = areas_2 + ['pool', 30]
areas_2 == areas
# Out:
# False

# %% [markdown]
# ### Functions

# %% [markdown]
# ** Built-in functions: ** <br>
# type( ), len(list), int( ), print( ), help( ), complex( ), max( ), sorted( )

# %% [markdown]
# ### Methods

# %% [markdown]
# Functions belong to specific objects, depending on the trype: <br>
# list.index( )
# list.count( )
# str.capitalize( ), str.upper( ), str.count( )
# str.replace( )
# Methods name can be the same for different types: list.index( ) and str.index( )
# Some methods can change the objects they are called on: list.append( ), .remove( ), .reverse( ) --> dangerous in programming

# %%
areas = [11.25, 18.0, 20.0, 10.75, 9.50]
print(areas.index(9.50))
print(areas.count(18.0))
# Out:
# 4
# 1

# %%
areas.append(12.0)
areas.reverse()
print(areas)
# Out:
# [12.0, 9.5, 10.75, 20.0, 18.0, 11.25]

# %% [markdown]
# ### Packagaes

# %%
import numpy

# %%
numpy.array([1,2,3])
# Out:
# array([1, 2, 3])

# %%
import numpy as np
np.array([1, 2, 3])
# Out:
# array([1, 2, 3])

# %%
from numpy import array
array([1, 2, 3])
# Out:
# array([1, 2, 3])

# %%
import math
math.pi
# Out:
# 3.141592653589793

# %%
from scipy.linalg import inv as my_inv
my_inv([[1,2],[3,4]])
# Out:
# array([[-2. ,  1. ],
#        [ 1.5, -0.5]])

# %% [markdown]
# #### NumPy
# Element-wise math operations on lists does not work. NumPy is the way to go ---> Numpy Array ( list )

# %% [markdown]
# ** Properties: **
# - Element-wise math operations.
# - Arrays contain only one type even if they are created by different types.
# - Array is a data type with its own methods and operations: list_1 + list_2 is different from array_1 + array_2
# - Subsetting works similar to lists

# %%
x = [4 , 9 , 6, 3, 1]
x[1]
import numpy as np
y = np.array(x)
y[1]
# Out:
# 9

# %%
y[y > 5]
# Out:
# array([9, 6])

# %%
np.array([True, 1, 2]) + np.array([3, 4, False])
# Out:
# array([4, 5, 2])

# %%
type(np.array([True, 1, 2]))
# Out:
# numpy.ndarray

# %%
# Create baseball, a list of lists
baseball = [[180, 78.4],
            [215, 102.7],
            [210, 98.5],
            [188, 75.2]]

# Import numpy
import numpy as np

# Create a 2D numpy array from baseball: np_baseball
np_baseball = np.array(baseball)
print(type(np_baseball))
print(np_baseball.shape)
# Out:
# <type 'numpy.ndarray'>
# (4, 2)

# %%
np_baseball[3,:]
# Out:
# array([ 188. ,   75.2])

# %%
import numpy as np
np_mat = np.array([[1, 2],
                   [3, 4],
                   [5, 6]])
print(np_mat * 2)
print(np_mat + np.array([10, 10]))
print(np_mat + np_mat)
# Out:
# [[ 2  4]
#  [ 6  8]
#  [10 12]]
# [[11 12]
#  [13 14]
#  [15 16]]
# [[ 2  4]
#  [ 6  8]
#  [10 12]]

# %%
height = np.round(np.random.normal(1.75, 0.2, 5000), 2)
weight = np.round(np.random.normal(62, 30, 5000), 2)

# %%
height.shape
# Out:
# (5000,)

# %%
np_city = np.column_stack((height, weight))

# %%
np_city.shape
# Out:
# (5000, 2)

# %%
np_city[:5,:]
# Out:
# array([[  1.57,  42.74],
#        [  1.99,  64.65],
#        [  1.57,  43.18],
#        [  1.52,  57.35],
#        [  1.63,  79.19]])

# %%
help(np.column_stack)
# Out:
# Help on function column_stack in module numpy.lib.shape_base:
#
# column_stack(tup)
#     Stack 1-D arrays as columns into a 2-D array.
#
#     Take a sequence of 1-D arrays and stack them as columns
#     to make a single 2-D array. 2-D arrays are stacked as-is,
#     just like with `hstack`.  1-D arrays are turned into 2-D columns
#     first.
#
#     Parameters
#     ----------
#     tup : sequence of 1-D or 2-D arrays.
#         Arrays to stack. All of them must have the same first dimension.
#
#     Returns
#     -------
#     stacked : 2-D array
#         The array formed by stacking the given arrays.
#
#     See Also
#     --------
#     hstack, vstack, concatenate
#
#     Examples
#     --------
#     >>> a = np.array((1,2,3))
#     >>> b = np.array((2,3,4))
#     >>> np.column_stack((a,b))
#     array([[1, 2],
#            [2, 3],
#            [3, 4]])

# %%
np.median(height)
# Out:
# 1.74

# %%
np.mean(weight)
# Out:
# 62.086840000000002

# %%
np.mean(np_city)
# Out:
# 31.916875000000001

# %%
np.mean(np_city[:,0])
# Out:
# 1.74691

# %%
np.mean(np_city[:,1])
# Out:
# 62.086840000000002

# %%
np.corrcoef(np_city[:,0],np_city[:,1])
# Out:
# array([[ 1.        , -0.01752318],
#        [-0.01752318,  1.        ]])

# %%
np.std(np_city[:,0])
# Out:
# 0.19560887479866551

# %% [markdown]
# ## Intermediate Paython

# %% [markdown]
# ### MATPLOTLIB
# ##### plot

# %%
year = [1950,
 1951,
 1952,
 1953,
 1954,
 1955,
 1956,
 1957,
 1958,
 1959,
 1960,
 1961,
 1962,
 1963,
 1964,
 1965,
 1966,
 1967,
 1968,
 1969,
 1970,
 1971,
 1972,
 1973,
 1974,
 1975,
 1976,
 1977,
 1978,
 1979,
 1980,
 1981,
 1982,
 1983,
 1984,
 1985,
 1986,
 1987,
 1988,
 1989,
 1990,
 1991,
 1992,
 1993,
 1994,
 1995,
 1996,
 1997,
 1998,
 1999,
 2000,
 2001,
 2002,
 2003,
 2004,
 2005,
 2006,
 2007,
 2008,
 2009,
 2010,
 2011,
 2012,
 2013,
 2014,
 2015,
 2016,
 2017,
 2018,
 2019,
 2020,
 2021,
 2022,
 2023,
 2024,
 2025,
 2026,
 2027,
 2028,
 2029,
 2030,
 2031,
 2032,
 2033,
 2034,
 2035,
 2036,
 2037,
 2038,
 2039,
 2040,
 2041,
 2042,
 2043,
 2044,
 2045,
 2046,
 2047,
 2048,
 2049,
 2050,
 2051,
 2052,
 2053,
 2054,
 2055,
 2056,
 2057,
 2058,
 2059,
 2060,
 2061,
 2062,
 2063,
 2064,
 2065,
 2066,
 2067,
 2068,
 2069,
 2070,
 2071,
 2072,
 2073,
 2074,
 2075,
 2076,
 2077,
 2078,
 2079,
 2080,
 2081,
 2082,
 2083,
 2084,
 2085,
 2086,
 2087,
 2088,
 2089,
 2090,
 2091,
 2092,
 2093,
 2094,
 2095,
 2096,
 2097,
 2098,
 2099,
 2100]

# %%
# The world popultion in Billions
pop = [2.53,
 2.57,
 2.62,
 2.67,
 2.71,
 2.76,
 2.81,
 2.86,
 2.92,
 2.97,
 3.03,
 3.08,
 3.14,
 3.2,
 3.26,
 3.33,
 3.4,
 3.47,
 3.54,
 3.62,
 3.69,
 3.77,
 3.84,
 3.92,
 4.0,
 4.07,
 4.15,
 4.22,
 4.3,
 4.37,
 4.45,
 4.53,
 4.61,
 4.69,
 4.78,
 4.86,
 4.95,
 5.05,
 5.14,
 5.23,
 5.32,
 5.41,
 5.49,
 5.58,
 5.66,
 5.74,
 5.82,
 5.9,
 5.98,
 6.05,
 6.13,
 6.2,
 6.28,
 6.36,
 6.44,
 6.51,
 6.59,
 6.67,
 6.75,
 6.83,
 6.92,
 7.0,
 7.08,
 7.16,
 7.24,
 7.32,
 7.4,
 7.48,
 7.56,
 7.64,
 7.72,
 7.79,
 7.87,
 7.94,
 8.01,
 8.08,
 8.15,
 8.22,
 8.29,
 8.36,
 8.42,
 8.49,
 8.56,
 8.62,
 8.68,
 8.74,
 8.8,
 8.86,
 8.92,
 8.98,
 9.04,
 9.09,
 9.15,
 9.2,
 9.26,
 9.31,
 9.36,
 9.41,
 9.46,
 9.5,
 9.55,
 9.6,
 9.64,
 9.68,
 9.73,
 9.77,
 9.81,
 9.85,
 9.88,
 9.92,
 9.96,
 9.99,
 10.03,
 10.06,
 10.09,
 10.13,
 10.16,
 10.19,
 10.22,
 10.25,
 10.28,
 10.31,
 10.33,
 10.36,
 10.38,
 10.41,
 10.43,
 10.46,
 10.48,
 10.5,
 10.52,
 10.55,
 10.57,
 10.59,
 10.61,
 10.63,
 10.65,
 10.66,
 10.68,
 10.7,
 10.72,
 10.73,
 10.75,
 10.77,
 10.78,
 10.79,
 10.81,
 10.82,
 10.83,
 10.84,
 10.85]

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
plt.plot(year, pop)
plt.show()

# %%
# life expectancy for each country data by professor Hans Rosling collected in 2007
life_exp = [43.828,
 76.423,
 72.301,
 42.731,
 75.32,
 81.235,
 79.829,
 75.635,
 64.062,
 79.441,
 56.728,
 65.554,
 74.852,
 50.728,
 72.39,
 73.005,
 52.295,
 49.58,
 59.723,
 50.43,
 80.653,
 44.74100000000001,
 50.651,
 78.553,
 72.961,
 72.889,
 65.152,
 46.462,
 55.322,
 78.782,
 48.328,
 75.748,
 78.273,
 76.486,
 78.332,
 54.791,
 72.235,
 74.994,
 71.33800000000002,
 71.878,
 51.57899999999999,
 58.04,
 52.947,
 79.313,
 80.657,
 56.735,
 59.448,
 79.406,
 60.022,
 79.483,
 70.259,
 56.007,
 46.38800000000001,
 60.916,
 70.19800000000001,
 82.208,
 73.33800000000002,
 81.757,
 64.69800000000001,
 70.65,
 70.964,
 59.545,
 78.885,
 80.745,
 80.546,
 72.567,
 82.603,
 72.535,
 54.11,
 67.297,
 78.623,
 77.58800000000002,
 71.993,
 42.592,
 45.678,
 73.952,
 59.44300000000001,
 48.303,
 74.241,
 54.467,
 64.164,
 72.801,
 76.195,
 66.803,
 74.543,
 71.164,
 42.082,
 62.069,
 52.90600000000001,
 63.785,
 79.762,
 80.204,
 72.899,
 56.867,
 46.859,
 80.196,
 75.64,
 65.483,
 75.53699999999998,
 71.752,
 71.421,
 71.688,
 75.563,
 78.098,
 78.74600000000002,
 76.442,
 72.476,
 46.242,
 65.528,
 72.777,
 63.062,
 74.002,
 42.56800000000001,
 79.972,
 74.663,
 77.926,
 48.159,
 49.339,
 80.941,
 72.396,
 58.556,
 39.613,
 80.884,
 81.70100000000002,
 74.143,
 78.4,
 52.517,
 70.616,
 58.42,
 69.819,
 73.923,
 71.777,
 51.542,
 79.425,
 78.242,
 76.384,
 73.747,
 74.249,
 73.422,
 62.698,
 42.38399999999999,
 43.487]

# %%
# GDP per capita (i.e. per person) for each country expressed in US Dollars.
gdp_cap = [974.5803384,
 5937.029525999998,
 6223.367465,
 4797.231267,
 12779.37964,
 34435.367439999995,
 36126.4927,
 29796.04834,
 1391.253792,
 33692.60508,
 1441.284873,
 3822.137084,
 7446.298803,
 12569.85177,
 9065.800825,
 10680.79282,
 1217.032994,
 430.0706916,
 1713.778686,
 2042.09524,
 36319.23501,
 706.016537,
 1704.063724,
 13171.63885,
 4959.114854,
 7006.580419,
 986.1478792,
 277.5518587,
 3632.557798,
 9645.06142,
 1544.750112,
 14619.222719999998,
 8948.102923,
 22833.30851,
 35278.41874,
 2082.4815670000007,
 6025.3747520000015,
 6873.262326000001,
 5581.180998,
 5728.353514,
 12154.08975,
 641.3695236000002,
 690.8055759,
 33207.0844,
 30470.0167,
 13206.48452,
 752.7497265,
 32170.37442,
 1327.60891,
 27538.41188,
 5186.050003,
 942.6542111,
 579.2317429999998,
 1201.637154,
 3548.3308460000007,
 39724.97867,
 18008.94444,
 36180.78919,
 2452.210407,
 3540.651564,
 11605.71449,
 4471.061906,
 40675.99635,
 25523.2771,
 28569.7197,
 7320.8802620000015,
 31656.06806,
 4519.461171,
 1463.249282,
 1593.06548,
 23348.139730000006,
 47306.98978,
 10461.05868,
 1569.331442,
 414.5073415,
 12057.49928,
 1044.770126,
 759.3499101,
 12451.6558,
 1042.581557,
 1803.151496,
 10956.99112,
 11977.57496,
 3095.7722710000007,
 9253.896111,
 3820.17523,
 823.6856205,
 944.0,
 4811.060429,
 1091.359778,
 36797.93332,
 25185.00911,
 2749.320965,
 619.6768923999998,
 2013.977305,
 49357.19017,
 22316.19287,
 2605.94758,
 9809.185636,
 4172.838464,
 7408.905561,
 3190.481016,
 15389.924680000002,
 20509.64777,
 19328.70901,
 7670.122558,
 10808.47561,
 863.0884639000002,
 1598.435089,
 21654.83194,
 1712.472136,
 9786.534714,
 862.5407561000002,
 47143.17964,
 18678.31435,
 25768.25759,
 926.1410683,
 9269.657808,
 28821.0637,
 3970.095407,
 2602.394995,
 4513.480643,
 33859.74835,
 37506.41907,
 4184.548089,
 28718.27684,
 1107.482182,
 7458.396326999998,
 882.9699437999999,
 18008.50924,
 7092.923025,
 8458.276384,
 1056.380121,
 33203.26128,
 42951.65309,
 10611.46299,
 11415.80569,
 2441.576404,
 3025.349798,
 2280.769906,
 1271.211593,
 469.70929810000007]

# %%
plt.plot(gdp_cap,life_exp)
plt.show()

# %%
plt.scatter(gdp_cap,life_exp)
plt.xscale('log')
plt.show()

# %%
# Population (in millions) of the correspoding countries above
pop = [31.889923,
 3.600523,
 33.333216,
 12.420476,
 40.301927,
 20.434176,
 8.199783,
 0.708573,
 150.448339,
 10.392226,
 8.078314,
 9.119152,
 4.552198,
 1.639131,
 190.010647,
 7.322858,
 14.326203,
 8.390505,
 14.131858,
 17.696293,
 33.390141,
 4.369038,
 10.238807,
 16.284741,
 1318.683096,
 44.22755,
 0.71096,
 64.606759,
 3.80061,
 4.133884,
 18.013409,
 4.493312,
 11.416987,
 10.228744,
 5.46812,
 0.496374,
 9.319622,
 13.75568,
 80.264543,
 6.939688,
 0.551201,
 4.906585,
 76.511887,
 5.23846,
 61.083916,
 1.454867,
 1.688359,
 82.400996,
 22.873338,
 10.70629,
 12.572928,
 9.947814,
 1.472041,
 8.502814,
 7.483763,
 6.980412,
 9.956108,
 0.301931,
 1110.396331,
 223.547,
 69.45357,
 27.499638,
 4.109086,
 6.426679,
 58.147733,
 2.780132,
 127.467972,
 6.053193,
 35.610177,
 23.301725,
 49.04479,
 2.505559,
 3.921278,
 2.012649,
 3.193942,
 6.036914,
 19.167654,
 13.327079,
 24.821286,
 12.031795,
 3.270065,
 1.250882,
 108.700891,
 2.874127,
 0.684736,
 33.757175,
 19.951656,
 47.76198,
 2.05508,
 28.90179,
 16.570613,
 4.115771,
 5.675356,
 12.894865,
 135.031164,
 4.627926,
 3.204897,
 169.270617,
 3.242173,
 6.667147,
 28.674757,
 91.077287,
 38.518241,
 10.642836,
 3.942491,
 0.798094,
 22.276056,
 8.860588,
 0.199579,
 27.601038,
 12.267493,
 10.150265,
 6.144562,
 4.553009,
 5.447502,
 2.009245,
 9.118773,
 43.997828,
 40.448191,
 20.378239,
 42.292929,
 1.133066,
 9.031088,
 7.554661,
 19.314747,
 23.174294,
 38.13964,
 65.068149,
 5.701579,
 1.056608,
 10.276158,
 71.158647,
 29.170398,
 60.776238,
 301.139947,
 3.447496,
 26.084662,
 85.262356,
 4.018332,
 22.211743,
 11.746035,
 12.311143]

# %%
plt.scatter(pop,life_exp)
plt.show()

# %% [markdown]
# #### histogram

# %%
plt.hist(life_exp)
plt.show()

# %%
plt.hist(life_exp, bins = 5)
plt.show()
plt.clf()
plt.hist(life_exp, bins = 20)
plt.show()

# %%
plt.hist(life_exp, bins = 5)
plt.show()
plt.hist(life_exp, bins = 20)
plt.show()

# %%
plt.scatter(gdp_cap, life_exp)
plt.xscale('log') 
plt.xlabel('GDP per Capita [in USD]')
plt.ylabel('Life Expectancy [in years]')
plt.title('World Development in 2007')
plt.show()

# %%
plt.scatter(gdp_cap, life_exp)
plt.xscale('log') 
plt.xlabel('GDP per Capita [in USD]')
plt.ylabel('Life Expectancy [in years]')
plt.xticks([1000, 10000, 100000],['1k', '10k', '100k'])
plt.title('World Development in 2007')
plt.show()

# %%
import numpy as np
np_pop = np.array(pop)
plt.scatter(gdp_cap, life_exp, s = 2 * np_pop) # s -> size
plt.xscale('log') 
plt.xlabel('GDP per Capita [in USD]')
plt.ylabel('Life Expectancy [in years]')
plt.xticks([1000, 10000, 100000],['1k', '10k', '100k'])
plt.title('World Development in 2007')
plt.show()

# %%
# a list with a color for each corresponding country, depending on the continent the country is part of.
# dict = {'Asia':'red','Europe':'green','Africa':'blue','Americas':'yellow','Oceania':'black'}

col = ['red',
 'green',
 'blue',
 'blue',
 'yellow',
 'black',
 'green',
 'red',
 'red',
 'green',
 'blue',
 'yellow',
 'green',
 'blue',
 'yellow',
 'green',
 'blue',
 'blue',
 'red',
 'blue',
 'yellow',
 'blue',
 'blue',
 'yellow',
 'red',
 'yellow',
 'blue',
 'blue',
 'blue',
 'yellow',
 'blue',
 'green',
 'yellow',
 'green',
 'green',
 'blue',
 'yellow',
 'yellow',
 'blue',
 'yellow',
 'blue',
 'blue',
 'blue',
 'green',
 'green',
 'blue',
 'blue',
 'green',
 'blue',
 'green',
 'yellow',
 'blue',
 'blue',
 'yellow',
 'yellow',
 'red',
 'green',
 'green',
 'red',
 'red',
 'red',
 'red',
 'green',
 'red',
 'green',
 'yellow',
 'red',
 'red',
 'blue',
 'red',
 'red',
 'red',
 'red',
 'blue',
 'blue',
 'blue',
 'blue',
 'blue',
 'red',
 'blue',
 'blue',
 'blue',
 'yellow',
 'red',
 'green',
 'blue',
 'blue',
 'red',
 'blue',
 'red',
 'green',
 'black',
 'yellow',
 'blue',
 'blue',
 'green',
 'red',
 'red',
 'yellow',
 'yellow',
 'yellow',
 'red',
 'green',
 'green',
 'yellow',
 'blue',
 'green',
 'blue',
 'blue',
 'red',
 'blue',
 'green',
 'blue',
 'red',
 'green',
 'green',
 'blue',
 'blue',
 'green',
 'red',
 'blue',
 'blue',
 'green',
 'green',
 'red',
 'red',
 'blue',
 'red',
 'blue',
 'yellow',
 'blue',
 'green',
 'blue',
 'green',
 'yellow',
 'yellow',
 'yellow',
 'red',
 'red',
 'red',
 'blue',
 'blue']

# %%
plt.scatter(gdp_cap, life_exp, s = 2 * np_pop, c = col, alpha = 0.8) # c -> color
plt.xscale('log') 
plt.xlabel('GDP per Capita [in USD]')
plt.ylabel('Life Expectancy [in years]')
plt.xticks([1000, 10000, 100000],['1k', '10k', '100k'])
plt.title('World Development in 2007')

# Additional customizations
plt.text(1550, 71, 'India')
plt.text(5700, 80, 'China')

# Add grid() call
plt.grid(True)

plt.show()

# %% [markdown]
# ### Dictionaries
# Unlike for lists, order of objects does NOT matter

# %%
countries = ['spain', 'france', 'germany', 'norway']
capitals = ['madrid', 'paris', 'berlin', 'oslo']

# %%
# not convenient way
print(capitals[countries.index('france')])
# Out:
# paris

# %%
europe = { 'spain':'madrid', 'france':'paris', 'germany':'berlin', 'norway':'oslo' }
print(europe)
# Out:
# {'norway': 'oslo', 'germany': 'berlin', 'spain': 'madrid', 'france': 'paris'}

# %%
type(europe)
# Out:
# dict

# %%
print(europe.keys())
# Out:
# ['norway', 'germany', 'spain', 'france']

# %%
print(europe.values())
# Out:
# ['oslo', 'berlin', 'madrid', 'paris']

# %%
print(europe['germany'])
# Out:
# berlin

# %% [markdown]
# ** Keys must be **
# - Unique
# - immutable objects (the value can't change after creation, unlike Lists)
#     - str, int, float, Boolean

# %% [markdown]
# #### Dictionary Manipulation

# %% [markdown]
# - ** Addition **

# %%
# Add italy to europe
europe["italy"] = "rome"

# %%
"italy" in europe
# Out:
# True

# %%
europe
# Out:
# {'france': 'paris',
#  'germany': 'berlin',
#  'italy': 'rome',
#  'norway': 'oslo',
#  'spain': 'madrid'}

# %% [markdown]
# - ** Update **

# %%
# Definition of dictionary
europe = {'spain':'madrid', 'france':'paris', 'germany':'bonn',
          'norway':'oslo', 'italy':'rome', 'poland':'warsaw',
          'australia':'vienna' }

# Update capital of germany
europe['germany'] = 'berlin'

# %%
europe
# Out:
# {'australia': 'vienna',
#  'france': 'paris',
#  'germany': 'berlin',
#  'italy': 'rome',
#  'norway': 'oslo',
#  'poland': 'warsaw',
#  'spain': 'madrid'}

# %% [markdown]
# - ** Remove **

# %%
# Remove australia
del(europe['australia'])
europe
# Out:
# {'france': 'paris',
#  'germany': 'berlin',
#  'italy': 'rome',
#  'norway': 'oslo',
#  'poland': 'warsaw',
#  'spain': 'madrid'}

# %% [markdown]
# #### Dictionary of dictionaries
# Dictionaries can contain key:value pairs where the values are again dictionaries.

# %%
europe = { 'spain': { 'capital':'madrid', 'population':46.77 },
           'france': { 'capital':'paris', 'population':66.03 },
           'germany': { 'capital':'berlin', 'population':80.62 },
           'norway': { 'capital':'oslo', 'population':5.084 } }

# %%
europe['germany']['population']
# Out:
# 80.62

# %%
# Create sub-dictionary data
data = {'capital':'rome', 'population':59.83}

# Add data to europe under key 'italy'
europe['italy'] = data

# %%
europe
# Out:
# {'france': {'capital': 'paris', 'population': 66.03},
#  'germany': {'capital': 'berlin', 'population': 80.62},
#  'italy': {'capital': 'rome', 'population': 59.83},
#  'norway': {'capital': 'oslo', 'population': 5.084},
#  'spain': {'capital': 'madrid', 'population': 46.77}}

# %% [markdown]
# ### Pandas
# - Tabular data type
# - Built on Numpy
# - 2D Numpy array only contains data with only similar types where as Panda's DataFrames can contain different types.
# - To create DataFrames:
#     - From Dict
#     - Read from files
# - Set row lables by ".index" attribute (note: Not method)

# %%
# Dictionary To DataFrames

# Pre-defined lists

# names, containing the country names for which data is available.
names = ['United States', 'Australia', 'Japan', 'India', 'Russia', 'Morocco', 'Egypt']

# a list with booleans that tells whether people drive left or right in the corresponding country.
dr =  [True, False, False, False, True, True, True]

# the number of motor vehicles per 1000 people in the corresponding country.
cpc = [809, 731, 588, 18, 200, 70, 45]

my_dict = {'country': names,'drives_right': dr, 'cars_per_cap': cpc }

import pandas as pd

cars = pd.DataFrame(my_dict)
cars
# Out:
#    cars_per_cap        country drives_right
# 0           809  United States         True
# 1           731      Australia        False
# 2           588          Japan        False
# 3            18          India        False
# 4           200         Russia         True
# 5            70        Morocco         True
# 6            45          Egypt         True

# %%
row_labels = ['US', 'AUS', 'JAP', 'IN', 'RU', 'MOR', 'EG']
cars.index = row_labels # This is an attribute and not method.
cars
# Out:
#      cars_per_cap        country drives_right
# US            809  United States         True
# AUS           731      Australia        False
# JAP           588          Japan        False
# IN             18          India        False
# RU            200         Russia         True
# MOR            70        Morocco         True
# EG             45          Egypt         True

# %%
# CSV to DataFrame
cars = pd.read_csv('cars.csv')
print(cars.shape)
cars
# Out:
# (7, 4)
#      ﻿  cars_per_cap        country drives_right
# 0   US           809  United States         True
# 1  AUS           731      Australia        False
# 2  JAP           588          Japan        False
# 3   IN            18          India        False
# 4   RU           200         Russia         True
# 5  MOR            70        Morocco         True
# 6   EG            45          Egypt         True

# %%
# CSV to DataFrame
cars = pd.read_csv('cars.csv', index_col = 0)
print(cars.shape)
cars
# Out:
# (7, 3)
#      cars_per_cap        country drives_right
# ﻿
# US            809  United States         True
# AUS           731      Australia        False
# JAP           588          Japan        False
# IN             18          India        False
# RU            200         Russia         True
# MOR            70        Morocco         True
# EG             45          Egypt         True

# %% [markdown]
# #### Square Brackets
# to select columns and rows (via slicing)

# %%
# Print out country column as Pandas Series
print(type(cars['country']))
cars['country']
# Out:
# <class 'pandas.core.series.Series'>
# ﻿
# US     United States
# AUS        Australia
# JAP            Japan
# IN             India
# RU            Russia
# MOR          Morocco
# EG             Egypt
# Name: country, dtype: object

# %%
# Print out country column as Pandas DataFrame
print(type(cars[['country']]))
cars[['country']]
# Out:
# <class 'pandas.core.frame.DataFrame'>
#            country
# ﻿
# US   United States
# AUS      Australia
# JAP          Japan
# IN           India
# RU          Russia
# MOR        Morocco
# EG           Egypt

# %%
cars[['country', 'drives_right']]
# Out:
#            country drives_right
# ﻿
# US   United States         True
# AUS      Australia        False
# JAP          Japan        False
# IN           India        False
# RU          Russia         True
# MOR        Morocco         True
# EG           Egypt         True

# %%
cars[1:4]
# Out:
#      cars_per_cap    country drives_right
# ﻿
# AUS           731  Australia        False
# JAP           588      Japan        False
# IN             18      India        False

# %% [markdown]
# #### loc(  ) and iloc(  )

# %%
cars.iloc[2,:]
# Out:
# cars_per_cap      588
# country         Japan
# drives_right    False
# Name: JAP, dtype: object

# %%
cars.iloc[2,0]
# Out:
# 588

# %%
type(cars.iloc[2,0])
# Out:
# numpy.int64

# %%
cars.iloc[[2],:]
# Out:
#      cars_per_cap country drives_right
# ﻿
# JAP           588   Japan        False

# %%
cars.iloc[[2,6],[1,2]]
# Out:
#     country drives_right
# ﻿
# JAP   Japan        False
# EG    Egypt         True

# %%
cars.loc['JAP']
# Out:
# cars_per_cap      588
# country         Japan
# drives_right    False
# Name: JAP, dtype: object

# %%
cars.loc[['JAP']]
# Out:
#      cars_per_cap country drives_right
# ﻿
# JAP           588   Japan        False

# %%
cars.loc[['JAP', 'US']]
# Out:
#      cars_per_cap        country drives_right
# ﻿
# JAP           588          Japan        False
# US            809  United States         True

# %%
cars.loc[['JAP', 'US'],['country','cars_per_cap']]
# Out:
#            country  cars_per_cap
# ﻿
# JAP          Japan           588
# US   United States           809

# %%
cars.loc['JAP','country']
# Out:
# 'Japan'

# %%
type(cars.loc['JAP','country'])
# Out:
# str

# %%
cars.loc[:,'country']
# Out:
# ﻿
# US     United States
# AUS        Australia
# JAP            Japan
# IN             India
# RU            Russia
# MOR          Morocco
# EG             Egypt
# Name: country, dtype: object

# %% [markdown]
# ### Logic, Control Flow and Filtering

# %%
# Equality
-5 * 15 != 75
# Out:
# True

# %%
True == 1
# Out:
# True

# %%
True > False
# Out:
# True

# %%
import numpy as np
my_house = np.array([18.0, 20.0, 10.75, 9.50])
print(my_house <= 18)
print(my_house[my_house <= 18])
# Out:
# [ True False  True  True]
# [ 18.    10.75   9.5 ]

# %%
my_kitchen = 18.0
# my_kitchen bigger than 10 and smaller than 18?
print(my_kitchen > 10 and my_kitchen < 18)
print(my_kitchen > 10 or my_kitchen < 18)
print(not my_kitchen > 10)
# Out:
# False
# True
# False

# %% [markdown]
# Before, the operational operators like < and >= worked with Numpy arrays out of the box. Unfortunately, this is not true for the boolean operators and, or, and not. To use these operators with Numpy, you will need np.logical_and(), np.logical_or() and np.logical_not()

# %%
print(np.logical_and(my_house < 18, my_house > 10))
# Out:
# [False False  True False]

# %%
print(my_house[np.logical_and(my_house < 18, my_house > 10)])
# Out:
# [ 10.75]

# %%
type(my_house[np.logical_and(my_house < 18, my_house > 10)])
# Out:
# numpy.ndarray

# %% [markdown]
# #### if, elif, else

# %%
# Define variables
room = "bed"

# if-elif-else construct for room
if room == "kit" :
    print("looking around in the kitchen.")
elif room == "bed":
    print("looking around in the bedroom.")
else :
    print("looking around elsewhere.")
# Out:
# looking around in the bedroom.

# %% [markdown]
# #### Filtering Pandas DataFrame

# %%
cars[cars['drives_right']]
# Out:
#      cars_per_cap        country drives_right
# ﻿
# US            809  United States         True
# RU            200         Russia         True
# MOR            70        Morocco         True
# EG             45          Egypt         True

# %%
cars[cars[['drives_right']]]
# Out:
#      cars_per_cap country  drives_right
# ﻿
# US            NaN     NaN             1
# AUS           NaN     NaN           NaN
# JAP           NaN     NaN           NaN
# IN            NaN     NaN           NaN
# RU            NaN     NaN             1
# MOR           NaN     NaN             1
# EG            NaN     NaN             1

# %%
cars[cars['cars_per_cap'] > 500]
# Out:
#      cars_per_cap        country drives_right
# ﻿
# US            809  United States         True
# AUS           731      Australia        False
# JAP           588          Japan        False

# %%
cars[np.logical_and(cars['cars_per_cap'] > 100, cars['cars_per_cap'] < 500)]
# Out:
#     cars_per_cap country drives_right
# ﻿
# RU           200  Russia         True

# %% [markdown]
# ### Loops

# %%
# Initialize offset
offset = 8

# Code the while loop
while offset != 0:
    print('correcting...')
    offset = offset -1
    print(offset)
# Out:
# correcting...
# 7
# correcting...
# 6
# correcting...
# 5
# correcting...
# 4
# correcting...
# 3
# correcting...
# 2
# correcting...
# 1
# correcting...
# 0

# %%
# Initialize offset
offset = -6

# Code the while loop
while offset != 0 :
    print("correcting...")
    if offset > 0 :
        offset = offset - 1
    else :
        offset = offset + 1        
    print(offset)
# Out:
# correcting...
# -5
# correcting...
# -4
# correcting...
# -3
# correcting...
# -2
# correcting...
# -1
# correcting...
# 0

# %% [markdown]
# ** For loop over **
# - list (var in seq)
# - list of lists (var in seq)
# - Dict (.items())
# - Numpy array
#     - 1D (var in seq)
#     - 2D (np.nditer(np_array))
# - Panda's DataFrame

# %%
# areas list
areas = [11.25, 18.0, 20.0, 10.75, 9.50]

# Code the for loop
for index, area in enumerate(areas):
    print("room " + str(index+1) + ": " + str(area))
# Out:
# room 1: 11.25
# room 2: 18.0
# room 3: 20.0
# room 4: 10.75
# room 5: 9.5

# %%
# house list of lists
house = [["hallway", 11.25], 
         ["kitchen", 18.0], 
         ["living room", 20.0], 
         ["bedroom", 10.75], 
         ["bathroom", 9.50]]
         
# Build a for loop from scratch
for room in house :
    print("The "+room[0]+" is "+str(room[1])+" sqm")
# Out:
# The hallway is 11.25 sqm
# The kitchen is 18.0 sqm
# The living room is 20.0 sqm
# The bedroom is 10.75 sqm
# The bathroom is 9.5 sqm

# %%
for key, value in europe.items():
     print("the capital of "+ key + " is " + value['capital'])
# Out:
# the capital of norway is oslo
# the capital of italy is rome
# the capital of germany is berlin
# the capital of spain is madrid
# the capital of france is paris

# %%
import numpy as np
np_height = np.array([5.7, 6.5, 7.2, 7.3])
np_weight = np.array([169, 175, 190, 220])
np_array = np.array([[5.7, 169], [6.5, 175], [7.2, 190], [7.3, 220]])
for el in np.nditer(np_array):
    print(el)
# Out:
# 5.7
# 169.0
# 6.5
# 175.0
# 7.2
# 190.0
# 7.3
# 220.0

# %%
for label, row in cars.iterrows():
    #print(label)
    #print(row)
    print(label + ": " + str(row["cars_per_cap"]))

# Code for loop that adds COUNTRY column
for lab, row in cars.iterrows():
    cars.loc[lab, "COUNTRY"] = row["country"].upper()
cars
# Out:
# US: 809
# AUS: 731
# JAP: 588
# IN: 18
# RU: 200
# MOR: 70
# EG: 45
#      cars_per_cap        country drives_right        COUNTRY
# ﻿
# US            809  United States         True  UNITED STATES
# AUS           731      Australia        False      AUSTRALIA
# JAP           588          Japan        False          JAPAN
# IN             18          India        False          INDIA
# RU            200         Russia         True         RUSSIA
# MOR            70        Morocco         True        MOROCCO
# EG             45          Egypt         True          EGYPT

# %%
cars["CAP"] = cars["country"].apply(str.upper)
cars
# Out:
#      cars_per_cap        country drives_right        COUNTRY            CAP
# ﻿
# US            809  United States         True  UNITED STATES  UNITED STATES
# AUS           731      Australia        False      AUSTRALIA      AUSTRALIA
# JAP           588          Japan        False          JAPAN          JAPAN
# IN             18          India        False          INDIA          INDIA
# RU            200         Russia         True         RUSSIA         RUSSIA
# MOR            70        Morocco         True        MOROCCO        MOROCCO
# EG             45          Egypt         True          EGYPT          EGYPT

# %% [markdown]
# ### RANDOM VAR

# %%
import numpy as np
np.random.seed(123)
np.random.rand()
# Out:
# 0.6964691855978616

# %%
np.random.randint(1,7) #rolling a dice
# Out:
# 3

# %% [markdown]
# #### Empire State Building Bet (reaching the 60th step)
# <img src=files/Empire.png , width=400, height=200, align="left">

# %%
import numpy as np
np.random.seed(123)

all_walk = [];

for x in range(500):

    random_walk = [0]
    step = 0

    for count in range(100):
        dice = np.random.randint(1,7)

        if dice <= 2:
            step = max(step - 1,0)
        elif dice <= 5:
            step = step + 1
        else:
            step = step + np.random.randint(1,7)

        if np.random.rand <= 0.001:
            step = 0
        
        random_walk.append(step)
    
    all_walk.append(random_walk[-1])
    
import matplotlib.pyplot as plt
plt.hist(all_walk, bins=10)
plt.show()

np_wk = np.array(all_walk)
sum (np_wk >= 60) / float(np_wk.size) * 100 # chance of reaching the 60th steps
# Out:
# 84.0

# %% [markdown]
# # Data Types
#
# ## Container Sequences (lists, sets, tuples, etc.)
#
# - Can be mutable (list, set) or immutable (tuple)
# - Iterable
#
# ### Lists
# - Ordered
# - Mutable
# - Index
# - Methods
#     - .append( )
#     - .extend( ) --> arg = lists, sets, tuples
#     - .index( )
#     - .pop( )

# %%
baby_names = ['Ximena', 'Aliza', 'Ayden','Calvin']
baby_names.append('Nima')
print("baby_names = "+ str(baby_names))
baby_names.extend(['Ali', 'Reza'])
print("baby_names = "+ str(baby_names))
baby_names.pop(baby_names.index('Ali'))
print("baby_names = "+ str(baby_names))
# Out:
# baby_names = ['Ximena', 'Aliza', 'Ayden', 'Calvin', 'Nima']
# baby_names = ['Ximena', 'Aliza', 'Ayden', 'Calvin', 'Nima', 'Ali', 'Reza']
# baby_names = ['Ximena', 'Aliza', 'Ayden', 'Calvin', 'Nima', 'Reza']

# %% [markdown]
# ### Tuples
# - Ordered
# - Immutable
# - Indexed
# - More memory effcient than lists
# - Pairing
# - Unpackable
# - To create tuples:
#     - brackets: (    ,     )
#     - trailing comma: nima = 'txt', --> nima = ('txt', )
#     - zip(seq1 [, seq2 [...]])
#     - enumerate(iterable[, start]): useful for obtaining an indexed list: (0, seq[0]), (1, seq[1]), (2, seq[2]), ...

# %%
girl_names = ['JADA','Emily','Ava','SERENITY','Claire','SOPHIA']
boy_names = ['JOSIAH','ETHAN','David','Jayden','MASON','RYAN']

pairs_wrong = (girl_names, boy_names) # tuple with 2 elements each being a list
print(pairs_wrong)

pairs_correct = zip(girl_names, boy_names) # tuple with 6 elements each being a string
print(pairs_correct)

for idx, pair in enumerate(pairs_correct):
    girl_name, boy_name = pair
    print('Rank {}: {} and {}'.format(idx+1, girl_name, boy_name))
# Out:
# (['JADA', 'Emily', 'Ava', 'SERENITY', 'Claire', 'SOPHIA'], ['JOSIAH', 'ETHAN', 'David', 'Jayden', 'MASON', 'RYAN'])
# [('JADA', 'JOSIAH'), ('Emily', 'ETHAN'), ('Ava', 'David'), ('SERENITY', 'Jayden'), ('Claire', 'MASON'), ('SOPHIA', 'RYAN')]
# Rank 1: JADA and JOSIAH
# Rank 2: Emily and ETHAN
# Rank 3: Ava and David
# Rank 4: SERENITY and Jayden
# Rank 5: Claire and MASON
# Rank 6: SOPHIA and RYAN

# %% [markdown]
# ### Sets
#
# - Unordered
# - Unique elements
# - ALWAYS created from a SINGLE list: set(    )
# - Mutable
# - Methods:
#     - .add(   ): single item
#     - .update(   ): merge a list or set
#     - .discard(   )
#     - .pop(   ): removes and returns a random element
#     - .union(  )
#     - .intersection(   )
#     - .difference( ): A.difference(B) = A - B

# %%
girl_names_set = set(girl_names)
boy_names_set = set(boy_names)

boy_names_set.add('Alix')
girl_names_set.add('Alix')

baby_names = boy_names_set.union(girl_names_set)
print('b Union g with {} elements: {} '.format(len(baby_names),baby_names))

common_names = boy_names_set.intersection(girl_names_set)
print('b Intersection g with {} elements: {} '.format(len(common_names),common_names))

diff_names = boy_names_set.difference(girl_names_set)
print('b Difference g with {} elements: {} '.format(len(diff_names), diff_names))
# Out:
# b Union g with 13 elements: set(['JOSIAH', 'JADA', 'SERENITY', 'Emily', 'RYAN', 'David', 'Alix', 'Claire', 'ETHAN', 'MASON', 'Ava', 'SOPHIA', 'Jayden'])
# b Intersection g with 1 elements: set(['Alix'])
# b Difference g with 6 elements: set(['JOSIAH', 'RYAN', 'David', 'ETHAN', 'MASON', 'Jayden'])

# %% [markdown]
# ### Dictionaries
#
# - Hold data in Key/Value pairs
# - Nestable
# - Iterable:
#     - .items( )
#     - for key in dict --> by defualt over keys
# - Created by dict( ) or { }
# - Safely finding a value for a key (no error if key does not exist): .get(key, 'custom err message')
# - .key( )
# - Using sorted( ) on a dictionary will sort by the keys of the dictionary -> output = list
# - Assign/Add new items:
#     -dict[key] = value
#     - .add( )
#     - .update( ) --> update the dict with a list of tuples or another dict
# - delete:
#     - del dict[key] : Err if key does not exist
#     - .pop(key) -> remove and return the removed item. No Err
# - to see if a key exists in a dictionary by using the "in" expression.

# %%
girl_names = {1: 'EMMA', 2: 'LEAH', 3: 'SARAH', 4: 'SOPHIA', 5: 'ESTHER'}

names = {}

for rank, name in girl_names.items():
    names[rank]=name
    
for rank in sorted(names,reverse=True)[:3]:
    print(names[rank])
# Out:
# ESTHER
# SOPHIA
# SARAH

# %%
names.get(3)
# Out:
# 'SARAH'

# %%
names.get(6, 'Erorr :) ')
# Out:
# 'Erorr :) '

# %%
timed_names = {2011: {}, 2012: names}
timed_names[2012][2]
# Out:
# 'LEAH'

# %%
for year in timed_names:
    print(year, timed_names[year].get(3, 'Unknown'))
# Out:
# (2011, 'Unknown')
# (2012, 'SARAH')

# %%
timed_names[2012].update([(6, 'Casey'), (7, 'Aiden')])
timed_names
# Out:
# {2011: {},
#  2012: {1: 'EMMA',
#   2: 'LEAH',
#   3: 'SARAH',
#   4: 'SOPHIA',
#   5: 'ESTHER',
#   6: 'Casey',
#   7: 'Aiden'}}

# %%
timed_names.pop(2011)
# Out:
# {}

# %%
timed_names
# Out:
# {2012: {1: 'EMMA',
#   2: 'LEAH',
#   3: 'SARAH',
#   4: 'SOPHIA',
#   5: 'ESTHER',
#   6: 'Casey',
#   7: 'Aiden'}}

# %%
2012 in timed_names
# Out:
# True

# %%
d = timed_names[2012]
d = {k : d[k] for k in d if not d[k].startswith('A')}
d
# Out:
# {1: 'EMMA', 2: 'LEAH', 3: 'SARAH', 4: 'SOPHIA', 5: 'ESTHER', 6: 'Casey'}

# %% [markdown]
# ### CSV Module
#
# - Python csv module
# - open( ) function provides a variable that represents a file, takes a path and a mode
# - csv.reader( ) reads a file object and returns the lines from the file as tuples
# - .close( ) method closes file objects
# - Creating a dictionary from a file: DictReader does just that

# %%
import csv
csvfile = open('cars.csv', 'r')
dict_cars = {}
for idx, row in enumerate(csv.reader(csvfile)):
    if idx != 0:
        dict_cars[row[0]] = row [1:]

print(dict_cars)
print(dict_cars.keys())
# Out:
# {'RU': ['200', 'Russia', 'TRUE'], 'MOR': ['70', 'Morocco', 'TRUE'], 'EG': ['45', 'Egypt', 'TRUE'], 'JAP': ['588', 'Japan', 'FALSE'], 'AUS': ['731', 'Australia', 'FALSE'], 'US': ['809', 'United States', 'TRUE'], 'IN': ['18', 'India', 'FALSE']}
# ['RU', 'MOR', 'EG', 'JAP', 'AUS', 'US', 'IN']

# %%
import csv
csvfile = open('cars.csv', 'r')
dict_cars = {}
for row in csv.DictReader(csvfile):
        lb = row.pop('\xef\xbb\xbf')
        #print(row)
        dict_cars[lb]=row
        
print(dict_cars)
print(dict_cars.keys())
# Out:
# {'RU': {'country': 'Russia', 'cars_per_cap': '200', 'drives_right': 'TRUE'}, 'MOR': {'country': 'Morocco', 'cars_per_cap': '70', 'drives_right': 'TRUE'}, 'EG': {'country': 'Egypt', 'cars_per_cap': '45', 'drives_right': 'TRUE'}, 'JAP': {'country': 'Japan', 'cars_per_cap': '588', 'drives_right': 'FALSE'}, 'AUS': {'country': 'Australia', 'cars_per_cap': '731', 'drives_right': 'FALSE'}, 'US': {'country': 'United States', 'cars_per_cap': '809', 'drives_right': 'TRUE'}, 'IN': {'country': 'India', 'cars_per_cap': '18', 'drives_right': 'FALSE'}}
# ['RU', 'MOR', 'EG', 'JAP', 'AUS', 'US', 'IN']

# %% [markdown]
# ### Collections Module
#
# #### Counter
#
# - You pass an iterable (list, set, tuple) or a dictionary to the Counter.
# - You can also use the Counter object similarly to a dictionary with key/value assignment, for example counter[key] = value
# - .most_common()

# %%
from collections import Counter
series = ['a', 'a', 'a', 'b', 'c','c', 'd']
series_count = Counter(series)
print(series_count['b'])
series_count
# Out:
# 1
# Counter({'a': 3, 'b': 1, 'c': 2, 'd': 1})

# %%
series_count.most_common(2)
# Out:
# [('a', 3), ('c', 2)]

# %% [markdown]
# #### Default Dictionary
#
# - Pass it a default type that every key will have even if it doesn't currently exist
# - Works exactly like a dictionary
# - When establishing a defaultdict, you pass it the type you want it to be, such as a list, tuple, set, int, string, dictionary or any other valid type object.

# %%
entries = [('hi',1), ('hello',2), ('hi',5), ('hello',7)]
from collections import defaultdict
def_dict = defaultdict(list)
for my_str, my_int in entries:
    def_dict[my_str].append(my_int)

def_dict
# Out:
# defaultdict(list, {'hello': [2, 7], 'hi': [1, 5]})

# %% [markdown]
# #### OrderedDict
#
# Recently in Python 3.6, dictionaries were made to maintain the order in which the keys were inserted; however, in all versions prior to that you need to use an OrderedDict to maintain insertion order.

# %%
from collections import OrderedDict
ord_dict = OrderedDict()
for my_str, my_int in entries:
    if my_str not in ord_dict.keys():
        ord_dict[my_str] = []
        #ord_dict[my_str] = 0
    ord_dict[my_str].append(my_int)
    #ord_dict[my_str] += my_int

print(ord_dict.items())
print(type(ord_dict))
print(type(ord_dict.items()))
print(ord_dict.popitem())
print(ord_dict.popitem(last=False))
# Out:
# [('hi', [1, 5]), ('hello', [2, 7])]
# <class 'collections.OrderedDict'>
# <type 'list'>
# ('hello', [2, 7])
# ('hi', [1, 5])

# %% [markdown]
# #### namedtuple
# - A tuple where each position (column) has a name
# - Ensure each one has the same properties
# - Alternative to a pandas DataFrame row
# - Each field is available as an attribute of the namedtuple
#
# For example, Cookie = namedtuple("Cookie", ['name', 'quantity']) will create a container, and you can create new ones of the type using Cookie('chocolate chip', 1) where you can access the name using the name attribute, and then get the quantity using the quantity attribute.

# %%
from collections import namedtuple

NmTup = namedtuple('NmTup',['string','quantity'])
NmTup_lst = []

for my_str, my_int in entries:
    
    NmTup_lst.append(NmTup(my_str, my_int))
    
print(NmTup)
print(type(NmTup))
print(NmTup_lst)
print(NmTup_lst[0].string)
print(NmTup_lst[0][1])
# Out:
# <class '__main__.NmTup'>
# <type 'type'>
# [NmTup(string='hi', quantity=1), NmTup(string='hello', quantity=2), NmTup(string='hi', quantity=5), NmTup(string='hello', quantity=7)]
# hi
# 1

# %% [markdown]
# ### DateTime
# - You'can use the .strptime() method from the datetime object, passing it both the string and the format. A full list of the format string components is available in the Python documentation.
# - Converting from a datetime object to a string is done with the .strftime() method on a instance of the datetime object. You pass a format string.
# - There is also a widely used string output standard called ISO-8601. It has a shortcut method named .isoformat(). I encourage you to use it anytime you write out to a file.
# - When working with datetime objects, you'll often want to group them by some component of the datetime such as the month, year, day, etc. Each of these are available as attributes on an instance of a datetime object.
# - The .now() method returns the current local time on the machine on which it is run, and .utcnow() does the same thing but returns the value in UTC time.
# - In order to work effectively with other timezones, you can use the pytz library. To use timezones, you need to import the timezone object from the pytz module. Then you can use the timezone constructor and pass it a name of a timezone, such as CT = timezone('US/Central'). You can get a full list of timezone names at Wikipedia.
# - In Python 3, you can make a datetime object "aware" by passing a timezone as the tzinfo keyword argument to the .replace() method on a datetime instance. An "aware" datetime object has an .astimezone() method that accepts a timezone object and returns a new datetime object in the desired timezone. If the tzinfo is not set for the datetime object it assumes the timezone of the computer you are working on.
# - The timedelta object from the datetime module is used to represent differences in datetime objects. You can create a timedelta by passing any number of keyword arguments such as days, seconds, microseconds, milliseconds, minutes, hours, and weeks to timedelta().
# - Once you have a timedelta object, you can add or subtract it from a datetime object to get a datetime object relative to the original datetime object.
# - Pendulum: a 3rd party module for date/time data type

# %%
dates_list = ['02/19/2001','04/10/2001','05/30/2001','07/19/2001','09/07/2001','10/27/2001','12/16/2001','02/04/2002']

from datetime import datetime

date_dt_lst = []

for date_st in dates_list:
    date_dt = datetime.strptime(date_st, '%m/%d/%Y')
    date_dt_lst.append(date_dt)
    print(date_dt)

print(type(date_dt))
print date_dt_lst

print '\n', "__________________________________", '\n'

for date_dt_itm in date_dt_lst:
    print 'STR: ', date_dt_itm.strftime('%m/%d/%Y')
    print 'ISO: ', date_dt_itm.isoformat()


print(type(date_dt_itm))
print type(date_dt_itm.strftime('%m/%d/%Y'))
print type(date_dt_itm.isoformat())
# Out:
# 2001-02-19 00:00:00
# 2001-04-10 00:00:00
# 2001-05-30 00:00:00
# 2001-07-19 00:00:00
# 2001-09-07 00:00:00
# 2001-10-27 00:00:00
# 2001-12-16 00:00:00
# 2002-02-04 00:00:00
# <type 'datetime.datetime'>
# [datetime.datetime(2001, 2, 19, 0, 0), datetime.datetime(2001, 4, 10, 0, 0), datetime.datetime(2001, 5, 30, 0, 0), datetime.datetime(2001, 7, 19, 0, 0), datetime.datetime(2001, 9, 7, 0, 0), datetime.datetime(2001, 10, 27, 0, 0), datetime.datetime(2001, 12, 16, 0, 0), datetime.datetime(2002, 2, 4, 0, 0)]
#
# __________________________________
#
# STR:  02/19/2001
# ISO:  2001-02-19T00:00:00
# STR:  04/10/2001
# ISO:  2001-04-10T00:00:00
# STR:  05/30/2001
# ISO:  2001-05-30T00:00:00
# STR:  07/19/2001
# ISO:  2001-07-19T00:00:00
# STR:  09/07/2001
# ISO:  2001-09-07T00:00:00
# STR:  10/27/2001
# ISO:  2001-10-27T00:00:00
# STR:  12/16/2001
# ISO:  2001-12-16T00:00:00
# STR:  02/04/2002
# ISO:  2002-02-04T00:00:00
# <type 'datetime.datetime'>
# <type 'str'>
# <type 'str'>

# %%
daily_summaries = [('01/01/2001', 'U', '297192', '126455', '423647'),
 ('01/02/2001', 'W', '780827', '501952', '1282779'),
 ('02/03/2001', 'W', '824923', '536432', '1361355'),
 ('02/04/2001', 'W', '870021', '550011', '1420032'),
 ('02/05/2001', 'W', '890426', '557917', '1448343'),
 ('03/06/2001', 'A', '577401', '255356', '832757')]

from datetime import datetime
from collections import defaultdict

dft_dict = defaultdict(int)

for item in daily_summaries:
    item_dt = datetime.strptime(item[0],'%m/%d/%Y')
    dft_dict[item_dt.month] += int(item[4])

print(dft_dict)
# Out:
# defaultdict(<type 'int'>, {1: 1706426, 2: 4229730, 3: 832757})

# %%
print datetime.now()
print datetime.utcnow() #PDT = UTC-07
# Out:
# 2019-07-20 23:35:39.812320
# 2019-07-21 06:35:39.812663

# %%
from pytz import timezone

chicago_usa_tz = timezone('US/Central')
ny_usa_tz = timezone('US/Eastern')

print chicago_usa_tz
print type(chicago_usa_tz)
# Out:
# US/Central
# <class 'pytz.tzfile.US/Central'>

# %%
daily_summaries = [(datetime(2001, 1, 1, 9, 18), '126455'),
 (datetime(2001, 1, 2, 6, 40), '501952'),
 (datetime(2001, 1, 3, 22, 24), '536432'),
 (datetime(2001, 1, 4, 17, 24), '550011'),
 (datetime(2001, 1, 5, 21, 17), '557917'),
 (datetime(2001, 1, 6, 16, 44), '255356'),
 (datetime(2001, 1, 7, 10, 57), '169825'),
 (datetime(2001, 1, 8, 20, 16), '590706'),
 (datetime(2001, 1, 9, 6, 30), '599905')]

for orig_dt, ridership in daily_summaries:
    chicago_dt = orig_dt.replace(tzinfo=chicago_usa_tz)
    ny_dt = chicago_dt.astimezone(ny_usa_tz)
    print('Chicago: %s, NY: %s, Ridership: %s' % (chicago_dt, ny_dt, ridership))
# Out:
# Chicago: 2001-01-01 09:18:00-05:51, NY: 2001-01-01 10:09:00-05:00, Ridership: 126455
# Chicago: 2001-01-02 06:40:00-05:51, NY: 2001-01-02 07:31:00-05:00, Ridership: 501952
# Chicago: 2001-01-03 22:24:00-05:51, NY: 2001-01-03 23:15:00-05:00, Ridership: 536432
# Chicago: 2001-01-04 17:24:00-05:51, NY: 2001-01-04 18:15:00-05:00, Ridership: 550011
# Chicago: 2001-01-05 21:17:00-05:51, NY: 2001-01-05 22:08:00-05:00, Ridership: 557917
# Chicago: 2001-01-06 16:44:00-05:51, NY: 2001-01-06 17:35:00-05:00, Ridership: 255356
# Chicago: 2001-01-07 10:57:00-05:51, NY: 2001-01-07 11:48:00-05:00, Ridership: 169825
# Chicago: 2001-01-08 20:16:00-05:51, NY: 2001-01-08 21:07:00-05:00, Ridership: 590706
# Chicago: 2001-01-09 06:30:00-05:51, NY: 2001-01-09 07:21:00-05:00, Ridership: 599905

# %%
from datetime import timedelta

glanceback = timedelta(days=30)
print daily_summaries[0][0]
print daily_summaries[0][0] - glanceback
print daily_summaries[1][0] - daily_summaries[0][0]
print type( daily_summaries[1][0] - daily_summaries[0][0])
# Out:
# 2001-01-01 09:18:00
# 2000-12-02 09:18:00
# 21:22:00
# <type 'datetime.timedelta'>

# %%
import csv

csvfile = open('crime_sampler.csv','r')

crime_data = []

for row in csv.reader(csvfile):
    
    crime_data.append((row[0], row[2], row[4], row[5]))

crime_data.pop(0)

print 'Dataset(first five rows):\n\n', crime_data[:5]
print '\n', "__________________________________", '\n'

from datetime import datetime
from collections import defaultdict
from collections import Counter

monthly_crimes = Counter()
#locations = defaultdict(list)
#locations_by_month = defaultdict(list)
locations = {}

for row in crime_data:
    date = datetime.strptime(row[0],'%m/%d/%Y %I:%M:%S %p')
    monthly_crimes[date.month] += 1
    #locations_by_month[date.month].append(row[2])
    if date.year not in locations.keys():
        locations[date.year] = {}
    if date.month not in locations[date.year].keys():
        locations[date.year][date.month] = set()
    locations[date.year][date.month].add(row[2])
    
print 'Monthly crimes:\n\n', monthly_crimes, '\n'
print 'Three most common crime rates: ',monthly_crimes.most_common(3), '\n'
print 'Locations in March 2016: ', locations[2016][3]
print '\n', "__________________________________", '\n'
# Out:
# Dataset(first five rows):
#
# [('05/23/2016 05:35:00 PM', 'ASSAULT', 'STREET', 'false'), ('03/26/2016 08:20:00 PM', 'BURGLARY', 'SMALL RETAIL STORE', 'false'), ('04/25/2016 03:05:00 PM', 'THEFT', 'DEPARTMENT STORE', 'true'), ('04/26/2016 05:30:00 PM', 'BATTERY', 'SIDEWALK', 'false'), ('06/19/2016 01:15:00 AM', 'BATTERY', 'SIDEWALK', 'false')]
#
# __________________________________
#
# Monthly crimes:
#
# Counter({1: 1948, 2: 1862, 7: 1257, 3: 1223, 8: 1218, 9: 1146, 6: 1136, 10: 1128, 5: 1092, 4: 1036, 11: 1026, 12: 928})
#
# Three most common crime rates:  [(1, 1948), (2, 1862), (7, 1257)]
#
# ...

# %%
import csv

csvfile = open('crime_sampler.csv','r')
crimes_by_district = defaultdict(list)

for row in csv.DictReader(csvfile):
    district = row.pop('District')
    crimes_by_district[district].append(row)
    
yearly_crimes = Counter()

for district, crimes in crimes_by_district.items():
    print district
    for crime in crimes:
        if crime['Arrest'] == 'true':
            year = datetime.strptime(crime['Date'], '%m/%d/%Y %I:%M:%S %p').year
            yearly_crimes[year] += 1
    print yearly_crimes
    
#print crimes_by_district['1']
# Out:
# 24
# Counter({2016: 51, 2017: 10})
# 25
# Counter({2016: 201, 2017: 36})
# 20
# Counter({2016: 228, 2017: 44})
# 22
# Counter({2016: 306, 2017: 56})
# 1
# Counter({2016: 430, 2017: 71})
# 3
# Counter({2016: 528, 2017: 89})
# 2
# Counter({2016: 612, 2017: 104})
# 5
# Counter({2016: 761, 2017: 134})
# 4
# Counter({2016: 895, 2017: 149})
# 7
# Counter({2016: 1076, 2017: 176})
# 6
# Counter({2016: 1233, 2017: 208})
# 9
# Counter({2016: 1349, 2017: 225})
# 8
# Counter({2016: 1473, 2017: 251})
# 11
# Counter({2016: 1748, 2017: 304})
# 10
# Counter({2016: 1892, 2017: 324})
# 12
# Counter({2016: 1964, 2017: 333})
# 15
# Counter({2016: 2118, 2017: 349})
# 14
# Counter({2016: 2177, 2017: 357})
# 17
# Counter({2016: 2215, 2017: 362})
# 16
# Counter({2016: 2281, 2017: 371})
# 19
# Counter({2016: 2369, 2017: 382})
# 18
# Counter({2016: 2461, 2017: 399})
# 31
# Counter({2016: 2462, 2017: 399})

# %% [markdown]
# # Python Data Science Toolbox Part-1
# ## Functions

# %%
def shout():
    """Print a string with three exclamation marks"""
    # Concatenate the strings: shout_word
    shout_word = 'congratulations' + "!!!"

    # Print shout_word
    print(shout_word)

# Call shout
shout()
# Out:
# congratulations!!!

# %%
# Define shout with the parameter, word
def shout(word):
    """Print a string with three exclamation marks"""
    # Concatenate the strings: shout_word
    shout_word = word + '!!!'

    # Print shout_word
    print(shout_word)

# Call shout with the string 'congratulations'
shout('congratulations')
# Out:
# congratulations!!!

# %%
def shout(word):
    """Return a string with three exclamation marks"""
    # Concatenate the strings: shout_word
    shout_word = word + '!!!'

    # Replace print with return
    return shout_word

# Pass 'congratulations' to shout: yell
yell = shout('congratulations')

# Print yell
print(yell)
# Out:
# congratulations!!!

# %%
# Define shout with parameters word1 and word2
def shout(word1, word2):
    """Concatenate strings with three exclamation marks"""
    # Concatenate word1 with '!!!': shout1
    shout1 = word1 + '!!!'
    
    # Concatenate word2 with '!!!': shout2
    shout2 = word2 + '!!!'
    
    # Concatenate shout1 with shout2: new_shout
    new_shout = shout1 + shout2 

    # Return new_shout
    return new_shout

# Pass 'congratulations' and 'you' to shout(): yell
yell = shout('congratulations', 'you')

# Print yell
print(yell)
# Out:
# congratulations!!!you!!!

# %%
# Define shout_all with parameters word1 and word2
def shout_all(word1, word2):
    
    # Concatenate word1 with '!!!': shout1
    shout1 = word1 + '!!!'
    
    # Concatenate word2 with '!!!': shout2
    shout2 = word2 + '!!!'
    
    # Construct a tuple with shout1 and shout2: shout_words
    shout_words = (shout1 , shout2)

    # Return shout_words
    return shout_words

# Pass 'congratulations' and 'you' to shout_all(): yell1, yell2
yell1, yell2 = shout_all('congratulations' , 'you')

# Print yell1 and yell2
print(yell1)
print(yell2)
# Out:
# congratulations!!!
# you!!!

# %% [markdown]
# #### Local vs. Enclosing fucntion local vs. Global vs. Built-in Scopes
# - LEGB rule: When Python sees an object or name in a fuction, it searches within the Local scope first, then the Enclosing function local scope (when nested), then Global, and then Built-in.
# - Python's built-in scope = a built-in module called builtins. However, to query builtins, you'll need to import builtins 'because the name builtins is not itself built in. After executing import builtins in the IPython Shell, execute dir(builtins) to print a list of all the names in the module builtins
# - The enclosing fuction in a nested functions returns
#     - a variable; or
#     - the inner fuction itself -> closure: This means that the nested or inner function remembers the state of its enclosing scope when called. Thus, anything defined locally in the enclosing scope is available to the inner function even when the outer function has finished execution.
# - "global" creates a global variable in the  function that can be changed inside the function and be recalled in the main program.
# - In nested fucntion, "nonlocal" creates a variable in the inner function that can be changed inside the inner function and be recalled in the enclosing function.
# - Arguments:
#      - Functions with one or multiple default argument
#      - Functions with variable-length arguments (*args): arg is a tuple inside the function
#      - Functions with variable-length keyword arguments (**kwargs): kwarge is a dictionary inside the function

# %%
# Create a string: team
team = "teen titans"

# Define change_team()
def change_team():
    """Change the value of the global variable team."""

    # Use team in global scope
    global team

    # Change the value of team in global: team
    team = "justice league"
# Print team
print(team)

# Call change_team()
change_team()

# Print team
print(team)
# Out:
# teen titans
# justice league

# %%
type(change_team())
# Out:
# NoneType

# %%
def three_shouts(word1, word2, word3):
    """Returns a tuple of strings
    concatenated with '!!!'."""

    # Define inner
    def inner(word):
        """Returns a string concatenated with '!!!'."""
        return word + '!!!'

    # Return a tuple of strings
    return (inner(word1), inner(word2), inner(word3))

# Call three_shouts() and print
print(three_shouts('a', 'b', 'c'))
# Out:
# ('a!!!', 'b!!!', 'c!!!')

# %%
# Define echo
def echo(n):
    """Return the inner_echo function."""

    # Define inner_echo
    def inner_echo(word1):
        """Concatenate n copies of word1."""
        echo_word = word1 * n
        return echo_word

    # Return inner_echo
    return inner_echo

# Call echo: twice
twice = echo(2)

# Call echo: thrice
thrice = echo(3)
# Call twice() and thrice() then print
print(twice('hello'), thrice('hello'))
# Out:
# ('hellohello', 'hellohellohello')

# %%
# Define shout_echo
def shout_echo(word1, echo=1):
    """Concatenate echo copies of word1 and three
     exclamation marks at the end of the string."""

    # Concatenate echo copies of word1 using *: echo_word
    echo_word = word1 * echo

    # Concatenate '!!!' to echo_word: shout_word
    shout_word = echo_word + '!!!'

    # Return shout_word
    return shout_word

# Call shout_echo() with "Hey": no_echo
no_echo = shout_echo("Hey")

# Call shout_echo() with "Hey" and echo=5: with_echo
with_echo = shout_echo("Hey",5)

# Print no_echo and with_echo
print(no_echo)
print(with_echo)
# Out:
# Hey!!!
# HeyHeyHeyHeyHey!!!

# %%
# Define shout_echo
def shout_echo(word1, echo = 1, intense = False):
    """Concatenate echo copies of word1 and three
    exclamation marks at the end of the string."""

    # Concatenate echo copies of word1 using *: echo_word
    echo_word = word1 * echo

    # Capitalize echo_word if intense is True
    if intense is True:
        # Capitalize and concatenate '!!!': echo_word_new
        echo_word_new = echo_word.upper() + '!!!'
    else:
        # Concatenate '!!!' to echo_word: echo_word_new
        echo_word_new = echo_word + '!!!'

    # Return echo_word_new
    return echo_word_new

# Call shout_echo() with "Hey", echo=5 and intense=True: with_big_echo
with_big_echo = shout_echo("Hey",5,True)

# Call shout_echo() with "Hey" and intense=True: big_no_echo
big_no_echo = shout_echo("Hey",intense=True)

# Print values
print(with_big_echo)
print(big_no_echo)
# Out:
# HEYHEYHEYHEYHEY!!!
# HEY!!!

# %%
# Define gibberish
def gibberish(*args):
    """Concatenate strings in *args together."""

    # Initialize an empty string: hodgepodge
    hodgepodge=""

    # Concatenate the strings in args
    for word in args:
        hodgepodge += word

    # Return hodgepodge
    return hodgepodge

# Call gibberish() with one string: one_word
one_word = gibberish("luke")

# Call gibberish() with five strings: many_words
many_words = gibberish("luke", "leia", "han", "obi", "darth")

# Print one_word and many_words
print(one_word)
print(many_words)
# Out:
# luke
# lukeleiahanobidarth

# %%
# Define report_status
def report_status(**kwargs):
    """Print out the status of a movie character."""

    print("\nBEGIN: REPORT\n")

    # Iterate over the key-value pairs of kwargs
    for key, value in kwargs.items():
        # Print out the keys and values, separated by a colon ':'
        print(key + ": " + value)

    print("\nEND REPORT")

# First call to report_status()
report_status(name="luke", affiliation="jedi", status="missing")

# Second call to report_status()
report_status(name="anakin", affiliation="sith lord", status="deceased")
# Out:
# BEGIN: REPORT
#
# status: missing
# affiliation: jedi
# name: luke
#
# END REPORT
#
# BEGIN: REPORT
#
# status: deceased
# affiliation: sith lord
# name: anakin
#
# END REPORT

# %% [markdown]
# #### lambda: map(), filter(), reduce()
# - map() applies a function over an object, such as a list. You can use lambda functions to define the function that map() will use to process the object.
# - The function filter() offers a way to filter out elements from a list that don't satisfy certain criteria.
# - The reduce() function is useful for performing some computation on a list and, unlike map() and filter(), returns a single value as a result. To use reduce(), you must import it from the functools module. Apply a function of two arguments cumulatively to the items of a sequence, from left to right, so as to reduce the sequence to a single value. For example, reduce(lambda x, y: x+y, [1, 2, 3, 4, 5]) calculates ((((1+2)+3)+4)+5). If initial is present, it is placed before the items of the sequence in the calculation, and serves as a default when the sequence is empty.

# %%
# Define echo_word as a lambda function: echo_word
echo_word = (lambda word1, echo: word1 * echo )

# Call echo_word: result
result = echo_word('hey',5)

# Print result
print(result)
# Out:
# heyheyheyheyhey

# %%
# Create a list of strings: spells
spells = ["protego", "accio", "expecto patronum", "legilimens"]

# Use map() to apply a lambda function over spells: shout_spells
shout_spells = map(lambda item: item + '!!!', spells)

# Convert shout_spells to a list: shout_spells_list
shout_spells_list = list(shout_spells)

# Convert shout_spells into a list and print it
print(shout_spells_list)
# Out:
# ['protego!!!', 'accio!!!', 'expecto patronum!!!', 'legilimens!!!']

# %%
# Create a list of strings: fellowship
fellowship = ['frodo', 'samwise', 'merry', 'pippin', 'aragorn', 'boromir', 'legolas', 'gimli', 'gandalf']

# Use filter() to apply a lambda function over fellowship: result
result = filter(lambda member: len(member) > 6, fellowship)

# Convert result to a list: result_list
result_list = list(result)

# Convert result into a list and print it
print(result_list)
# Out:
# ['samwise', 'aragorn', 'boromir', 'legolas', 'gandalf']

# %%
# Import reduce from functools
from functools import reduce

# Create a list of strings: stark
stark = ['robb', 'sansa', 'arya', 'brandon', 'rickon']

# Use reduce() to apply a lambda function over stark: result
result = reduce(lambda item1, item2: item1 + item2, stark)

# Print the result
print(result)
# Out:
# robbsansaaryabrandonrickon

# %% [markdown]
# #### Error handling with try-except

# %%
# Define shout_echo
def shout_echo(word1, echo=1):
    """Concatenate echo copies of word1 and three
    exclamation marks at the end of the string."""

    # Initialize empty strings: echo_word, shout_words
    
    echo_word = ""
    shout_words = ""

    # Add exception handling with try-except
    try:
        # Concatenate echo copies of word1 using *: echo_word
        echo_word = word1 * echo

        # Concatenate '!!!' to echo_word: shout_words
        shout_words = echo_word + '!!!'
    except:
        # Print error message
        print("word1 must be a string and echo must be an integer.")

    # Return shout_words
    return shout_words

# Call shout_echo
shout_echo("particle", echo="accelerator")
# Out:
# word1 must be a string and echo must be an integer.
# ''

# %%
# Define shout_echo
def shout_echo(word1, echo=1):
    """Concatenate echo copies of word1 and three
    exclamation marks at the end of the string."""

    # Raise an error with raise
    if echo < 0:
        raise ValueError('echo must be greater than 0')
    # Concatenate echo copies of word1 using *: echo_word
    echo_word = word1 * echo

    # Concatenate '!!!' to echo_word: shout_word
    shout_word = echo_word + '!!!'

    # Return shout_word
    return shout_word

# Call shout_echo
shout_echo("particle", echo=-2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-6325ddf8bc68> in <module>
#      17
#      18 # Call shout_echo
# ---> 19 shout_echo("particle", echo=-2)
#
# <ipython-input-9-6325ddf8bc68> in shout_echo(word1, echo)
#       6     # Raise an error with raise
#       7     if echo < 0:
# ----> 8         raise ValueError('echo must be greater than 0')
#       9     # Concatenate echo copies of word1 using *: echo_word
#      10     echo_word = word1 * echo
#
# ValueError: echo must be greater than 0

# %% [markdown]
# # Data Visualization
# ## Customizing plots

# %%
import numpy as np

# Enumerating years from 1970 to 2011 inclusive
year = np.array([1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980,
       1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991,
       1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002,
       2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011])

# Representing the percentage of Physical Sciences degrees awarded to women each in corresponding year
physical_sciences = np.array([13.8, 14.9, 14.8, 16.5, 18.2, 19.1, 20. , 21.3, 22.5, 23.7, 24.6,
       25.7, 27.3, 27.6, 28. , 27.5, 28.4, 30.4, 29.7, 31.3, 31.6, 32.6,
       32.6, 33.6, 34.8, 35.9, 37.3, 38.3, 39.7, 40.2, 41. , 42.2, 41.1,
       41.7, 42.1, 41.6, 40.8, 40.7, 40.7, 40.7, 40.2, 40.1])

# Representing the percentage of Computer Science degrees awarded to women in each corresponding year
computer_science = np.array([13.6, 13.6, 14.9, 16.4, 18.9, 19.8, 23.9, 25.7, 28.1, 30.2, 32.5,
       34.8, 36.3, 37.1, 36.8, 35.7, 34.7, 32.4, 30.8, 29.9, 29.4, 28.7,
       28.2, 28.5, 28.5, 27.5, 27.1, 26.8, 27. , 28.1, 27.7, 27.6, 27. ,
       25.1, 22.2, 20.6, 18.6, 17.6, 17.8, 18.1, 17.6, 18.2])

health = np.array([77.1, 75.5, 76.9, 77.4, 77.9, 78.9, 79.2, 80.5, 81.9, 82.3, 83.5,
       84.1, 84.4, 84.6, 85.1, 85.3, 85.7, 85.5, 85.2, 84.6, 83.9, 83.5,
       83. , 82.4, 81.8, 81.5, 81.3, 81.9, 82.1, 83.5, 83.5, 85.1, 85.8,
       86.5, 86.5, 86. , 85.9, 85.4, 85.2, 85.1, 85. , 84.8])

education = np.array([74.53532758, 74.14920369, 73.55451996, 73.50181443, 73.33681143,
       72.80185448, 72.16652471, 72.45639481, 73.19282134, 73.82114234,
       74.98103152, 75.84512345, 75.84364914, 75.95060123, 75.86911601,
       75.92343971, 76.14301516, 76.96309168, 77.62766177, 78.11191872,
       78.86685859, 78.99124597, 78.43518191, 77.26731199, 75.81493264,
       75.12525621, 75.03519921, 75.1637013 , 75.48616027, 75.83816206,
       76.69214284, 77.37522931, 78.64424394, 78.54494815, 78.65074774,
       79.06712173, 78.68630551, 78.72141311, 79.19632674, 79.5329087 ,
       79.61862451, 79.43281184])

# %%
import matplotlib.pyplot as plt

plt.plot(year, physical_sciences, color='blue')

plt.plot(year, computer_science, color='red')

plt.show()

# %% [markdown]
# ### Using axes()
# In calling plt.axes([xlo, ylo, width, height]), a set of axes is created and made active with lower corner at coordinates (xlo, ylo) of the specified width and height. Note that these coordinates can be passed to plt.axes() in the form of a list or a tuple.
#
# The coordinates and lengths are values between 0 and 1 representing lengths relative to the dimensions of the figure. After issuing a

# %%
plt.axes([0.05, 0.05, 0.425, 0.9])
plt.plot(year, physical_sciences, color='blue')
plt.title('Physical Sciences')

plt.axes([0.525, 0.05, 0.425, 0.9])
plt.plot(year, computer_science, color='red')
plt.title('Computer Science')

plt.show()

# %% [markdown]
# ### Using subplot()
# The command plt.axes() requires a lot of effort to use well because the coordinates of the axes need to be set manually. A better alternative is to use plt.subplot() to determine the layout automatically. plt.subplot(m, n, k) to make the subplot grid of dimensions m by n and to make the kth subplot active (subplots are numbered starting from 1 row-wise from the top left corner of the subplot grid).
# - Use plt.tight_layout() to improve the spacing between subplots

# %%
plt.subplot(1,2,1)
plt.plot(year, physical_sciences, color='blue')
plt.title('Physical Sciences')

plt.subplot(1,2,2)
plt.plot(year, computer_science, color='red')
plt.title('Computer Science')

# Use plt.tight_layout() to improve the spacing between subplots
plt.tight_layout()

plt.show()

# %%
# Create a figure with 2x2 subplot layout and make the top left subplot active
plt.subplot(2,2,1)

# Plot in blue the % of degrees awarded to women in the Physical Sciences
plt.plot(year, physical_sciences, color='blue')
plt.title('Physical Sciences')

# Make the top right subplot active in the current 2x2 subplot grid 
plt.subplot(2,2,2)

# Plot in red the % of degrees awarded to women in Computer Science
plt.plot(year, computer_science, color='red')
plt.title('Computer Science')

# Make the bottom left subplot active in the current 2x2 subplot grid
plt.subplot(2,2,3)

# Plot in green the % of degrees awarded to women in Health Professions
plt.plot(year, health, color='green')
plt.title('Health Professions')

# Make the bottom right subplot active in the current 2x2 subplot grid
plt.subplot(2,2,4)

# Plot in yellow the % of degrees awarded to women in Education
plt.plot(year, education, color='yellow')
plt.title('Education')

# Improve the spacing between subplots and display them
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Customizing Axis

# %%
# Plot the % of degrees awarded to women in Computer Science and the Physical Sciences
plt.plot(year,computer_science, color='red') 
plt.plot(year, physical_sciences, color='blue')

# Add the axis labels
plt.xlabel('Year')
plt.ylabel('Degrees awarded to women (%)')

# Set the x-axis range
plt.xlim([1990,2010])

# Set the y-axis range
plt.ylim([0,50])

# Add a title and display the plot
plt.title('Degrees awarded to women (1990-2010)\nComputer Science (red)\nPhysical Sciences (blue)')

# Save the image as 'xlim_and_ylim.png'
plt.savefig('xlim_and_ylim.png')

plt.show()

# %%
# Plot in blue the % of degrees awarded to women in Computer Science
plt.plot(year,computer_science, color='blue')

# Plot in red the % of degrees awarded to women in the Physical Sciences
plt.plot(year, physical_sciences,color='red')

# Set the x-axis and y-axis limits
plt.axis((1990,2010,0,50))

# Show the figure
plt.show()

# %% [markdown]
# ### Legend, Annotating, and Style

# %%
# Specify the label 'Computer Science'
plt.plot(year, computer_science, color='red', label='Computer Science') 

# Specify the label c 
plt.plot(year, physical_sciences, color='blue', label='Physical Sciences')

# Add a legend at the lower center
plt.legend(loc='upper left')

# Add axis labels and title
plt.xlabel('Year')
plt.ylabel('Enrollment (%)')
plt.title('Undergraduate enrollment of women')
plt.show()

# %%
# Plot with legend as before
plt.plot(year, computer_science, color='red', label='Computer Science') 
plt.plot(year, physical_sciences, color='blue', label='Physical Sciences')
plt.legend(loc='lower center')

# Compute the maximum enrollment of women in Computer Science: cs_max
cs_max = computer_science.max()

# Calculate the year in which there was maximum enrollment of women in Computer Science: yr_max
yr_max = year[computer_science.argmax()]

# Add a black arrow annotation
plt.annotate('Maximum', xy = (yr_max, cs_max), xytext = (yr_max+5, cs_max+5), arrowprops = dict(facecolor='black') )

# Add axis labels and title
plt.xlabel('Year')
plt.ylabel('Enrollment (%)')
plt.title('Undergraduate enrollment of women')
plt.show()

# %%
print(plt.style.available)
# Out:
# ['seaborn-dark', 'seaborn-darkgrid', 'seaborn-ticks', 'fivethirtyeight', 'seaborn-whitegrid', 'classic', '_classic_test', 'fast', 'seaborn-talk', 'seaborn-dark-palette', 'seaborn-bright', 'seaborn-pastel', 'grayscale', 'seaborn-notebook', 'ggplot', 'seaborn-colorblind', 'seaborn-muted', 'seaborn', 'Solarize_Light2', 'seaborn-paper', 'bmh', 'tableau-colorblind10', 'seaborn-white', 'dark_background', 'seaborn-poster', 'seaborn-deep']

# %%
plt.clf()
# Set the style to 'ggplot'
plt.style.use('ggplot')

# Create a figure with 2x2 subplot layout
plt.subplot(2, 2, 1) 

# Plot the enrollment % of women in the Physical Sciences
plt.plot(year, physical_sciences, color='blue')
plt.title('Physical Sciences')

# Plot the enrollment % of women in Computer Science
plt.subplot(2, 2, 2)
plt.plot(year, computer_science, color='red')
plt.title('Computer Science')

# Add annotation
cs_max = computer_science.max()
yr_max = year[computer_science.argmax()]
plt.annotate('Maximum', xy=(yr_max, cs_max), xytext=(yr_max-1, cs_max-10), arrowprops=dict(facecolor='black'))

# Plot the enrollmment % of women in Health professions
plt.subplot(2, 2, 3)
plt.plot(year, health, color='green')
plt.title('Health Professions')

# Plot the enrollment % of women in Education
plt.subplot(2, 2, 4)
plt.plot(year, education, color='yellow')
plt.title('Education')

# Improve spacing between subplots and display them
plt.tight_layout()
plt.show()

# back to default style
plt.rcParams.update(plt.rcParamsDefault)

# %% [markdown]
# ## 2D Arrays
# In order to visualize two-dimensional arrays of data, it is necessary to understand how to generate and manipulate 2-D arrays. Many Matplotlib plots support arrays as input and in particular, they support NumPy arrays.
# - use the meshgrid function in NumPy to generate 2-D arrays which you will then visualize using plt.imshow()

# %%
import numpy as np
import matplotlib.pyplot as plt

u = np.linspace(-2, 2, 41)
v = np.linspace(-1, 1, 21)

X, Y = np.meshgrid(u,v)

Z = np.sin(3*np.sqrt(X**2+Y**2))
plt.pcolor(Z)
plt.savefig('sine_mesh.png')
plt.show()

# %%
A = np.array([[1, 0, -1], [2, 0, 1], [1, 1, 1]])
plt.pcolor(A, cmap='Blues')
plt.colorbar()
plt.show()

# %% [markdown]
# ### Contour & filled contour plots
# Two types of contour plot supported by Matplotlib are plt.contour() and plt.contourf() where the former displays the contours as lines and the latter displayed filled areas between contours. Both these plotting commands accept a two dimensional array from which the appropriate contours are computed.

# %%
# Generate a default contour map of the array Z
plt.subplot(2,2,1)
plt.contour(X,Y,Z)

# Generate a contour map with 20 contours
plt.subplot(2,2,2)
plt.contour(X,Y,Z,20)

# Generate a default filled contour map of the array Z
plt.subplot(2,2,3)
plt.contourf(X,Y,Z)

# Generate a default filled contour map with 20 contours
plt.subplot(2,2,4)
plt.contourf(X,Y,Z,20)

# Improve the spacing between subplots
plt.tight_layout()

# Display the figure
plt.show()

# %% [markdown]
# ### cmap
# When displaying a 2-D array with plt.imshow() or plt.pcolor(), the values of the array are mapped to a corresponding color. The set of colors used is determined by a colormap which smoothly maps values to colors, making it easy to understand the structure of the data at a glance.
#
# It is often useful to change the colormap from the default 'jet' colormap used by matplotlib. A good colormap is visually pleasing and conveys the structure of the data faithfully and in a way that makes sense for the application.
#
# - Some matplotlib colormaps have unique names such as 'jet', 'coolwarm', 'magma' and 'viridis'.
# - Others have a naming scheme based on overall color such as 'Greens', 'Blues', 'Reds', and 'Purples'.
# - Another four colormaps are based on the seasons, namely 'summer', 'autumn', 'winter' and 'spring'.
# - You can insert the option cmap=<name> into most matplotlib functions to change the color map of the resulting plot.
# - Be sure to also add a color bar to each filled contour plot with plt.colorbar().

# %%
# Create a filled contour plot with a color map of 'viridis'
plt.subplot(2,2,1)
plt.contourf(X,Y,Z,20, cmap='viridis')
plt.colorbar()
plt.title('Viridis')

# Create a filled contour plot with a color map of 'gray'
plt.subplot(2,2,2)
plt.contourf(X,Y,Z,20, cmap='Blues')
plt.colorbar()
plt.title('Blues')

# Create a filled contour plot with a color map of 'autumn'
plt.subplot(2,2,3)
plt.contourf(X,Y,Z,20, cmap='autumn')
plt.colorbar()
plt.title('Autumn')

# Create a filled contour plot with a color map of 'winter'
plt.subplot(2,2,4)
plt.contourf(X,Y,Z,20, cmap='winter')
plt.colorbar()
plt.title('Winter')

# Improve the spacing between subplots and display them
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Bivariate Distribution

# %% [markdown]
# plt.hist2d()
#
# - You specify the coordinates of the points using plt.hist2d(x,y) assuming x and y are two vectors of the same length.
# - You can specify the number of bins with the argument bins=(nx, ny) where nx is the number of bins to use in the horizontal direction and ny is the number of bins to use in the vertical direction.
# - You can specify the rectangular region in which the samples are counted in constructing the 2D histogram. The optional parameter required is range=((xmin, xmax), (ymin, ymax)) where
#     - xmin and xmax are the respective lower and upper limits for the variables on the x-axis and
#     - ymin and ymax are the respective lower and upper limits for the variables on the y-axis. Notice that the optional range argument can use nested tuples or lists.

# %%
mpg = np.array([18. ,  9. , 36.1, 18.5, 34.3, 32.9, 32.2, 22. , 15. , 17. , 44. ,
       24.5, 32. , 14. , 15. , 13. , 36. , 31. , 32. , 21.5, 19. , 17. ,
       16. , 15. , 23. , 26. , 32. , 24. , 21. , 31.3, 32.7, 15. , 23. ,
       17.6, 28. , 24. , 14. , 18.1, 36. , 29. , 35.1, 36. , 16.5, 16. ,
       29.9, 31. , 27.2, 14. , 32.1, 15. , 12. , 17.6, 25. , 28.4, 29. ,
       30.9, 20. , 20.8, 22. , 38. , 31. , 19. , 16. , 25. , 22. , 26. ,
       13. , 19.9, 11. , 28. , 15.5, 26. , 14. , 12. , 24.2, 25. , 22.5,
       26.8, 23. , 26. , 30.7, 31. , 27.2, 21.5, 29. , 20. , 13. , 14. ,
       38. , 13. , 24.5, 13. , 25. , 24. , 34.1, 13. , 44.6, 20.5, 18. ,
       23.2, 20. , 24. , 25.5, 36.1, 23. , 24. , 18. , 26.6, 32. , 20.3,
       27. , 17. , 21. , 13. , 24. , 17. , 39.1, 14.5, 13. , 20.2, 27. ,
       35. , 15. , 36.4, 30. , 31.9, 26. , 16. , 20. , 18.6, 14. , 25. ,
       33. , 14. , 18.5, 37.2, 18. , 44.3, 18. , 28. , 43.4, 20.6, 19.2,
       26.4, 18. , 28. , 26. , 13. , 25.8, 28.1, 13. , 16.5, 31.5, 24. ,
       15. , 18. , 33.5, 32.4, 27. , 13. , 31. , 28. , 27.2, 21. , 19. ,
       25. , 23. , 19. , 15.5, 23.9, 22. , 29. , 14. , 15. , 27. , 15. ,
       30.5, 25. , 17.5, 34. , 38. , 30. , 19.8, 25. , 21. , 26. , 16.5,
       18.1, 46.6, 21.5, 14. , 21.6, 15.5, 20.5, 23.9, 12. , 20.2, 34.4,
       23. , 24.3, 19. , 29. , 23.5, 34. , 37. , 33. , 18. , 15. , 34.7,
       19.4, 32. , 34.1, 33.7, 20. , 15. , 38.1, 26. , 27. , 16. , 17. ,
       13. , 28. , 14. , 31.5, 34.5, 11. , 16. , 31.6, 19.1, 18.5, 15. ,
       18. , 35. , 20.2, 13. , 31. , 22. , 11. , 33.5, 43.1, 25.4, 40.8,
       14. , 29.8, 16. , 20.6, 18. , 33. , 31.8, 13. , 20. , 32. , 13. ,
       23.7, 19.2, 37. , 18. , 19. , 32.3, 18. , 13. , 12. , 36. , 18.2,
       19. , 30. , 15. , 11. , 10. , 16. , 14. , 16.9, 13. , 25. , 21. ,
       21.1, 26. , 28. , 29. , 16. , 26.6, 19. , 32.8, 22. , 19. , 31. ,
       23. , 29.5, 17.5, 19. , 24. , 14. , 28. , 21. , 22.4, 36. , 18. ,
       16.2, 39.4, 30. , 18. , 17.5, 28.8, 22. , 34.2, 30.5, 16. , 38. ,
       41.5, 27.9, 22. , 29.8, 17.7, 15. , 14. , 15.5, 17.5, 12. , 29. ,
       15.5, 35.7, 26. , 30. , 33.8, 18. , 13. , 20. , 32.4, 16. , 27.5,
       23. , 14. , 17. , 16. , 23. , 24. , 27. , 15. , 27. , 28. , 14. ,
       33.5, 39. , 24. , 26.5, 19.4, 15. , 25.5, 14. , 27.4, 13. , 19. ,
       17. , 28. , 22. , 30. , 18. , 14. , 22. , 23.8, 24. , 26. , 26. ,
       30. , 29. , 14. , 25.4, 19. , 12. , 20. , 27. , 22.3, 10. , 19.2,
       26. , 16. , 37.3, 26. , 20.2, 13. , 21. , 25. , 20.5, 37.7, 36. ,
       20. , 37. , 18. , 27. , 29.5, 17.5, 25.1])

hp = np.array([ 88, 193,  60,  98,  78, 100,  75,  76, 130, 140,  52,  88,  84,
       148, 150, 130,  58,  82,  65, 110,  95, 110, 140, 170,  78,  90,
        96,  95, 110,  75, 132, 150,  83,  85,  86,  75, 140, 139,  70,
        52,  60,  84, 138, 180,  65,  67,  97, 150,  70, 100, 180, 129,
        95,  90,  83,  75, 100,  85, 112,  67,  65,  88, 100,  75, 100,
        70, 145, 110, 210,  80, 145,  69, 150, 198, 120,  92,  90, 115,
        95,  75,  76,  67,  71, 115,  84,  91, 150, 215,  67, 175,  60,
       175, 110,  95,  68, 150,  67,  95, 110, 105, 102, 110,  89,  66,
        88,  75,  78, 105,  70, 103,  60, 150,  72, 170,  90, 110,  58,
       152, 145, 139,  83,  69, 150,  67,  80,  71,  46, 105,  90, 110,
       175,  80,  74, 150, 150,  65, 100,  48, 105,  90,  48, 105, 105,
        88, 100,  75, 113, 190,  92,  80, 165, 180,  71,  97,  72, 105,
        90,  75,  88, 155,  68,  90,  84,  87, 112,  87, 125, 108, 142,
        97, 105,  75, 137, 150,  88, 145,  63,  95, 140,  88,  85,  70,
        85, 115,  86,  79, 120, 120,  65, 110, 220, 115, 170, 100,  90,
       225,  85,  65,  97,  90,  90,  49, 110,  70,  92,  53, 100, 190,
        63,  90,  67,  65,  75, 100, 110,  60,  93,  88, 150, 100, 150,
        88, 225,  68,  70, 208, 105,  74,  90, 110,  72,  97,  88,  88,
       129,  85,  86, 150,  70,  48,  77,  65, 175,  90, 150, 110, 130,
        53,  65, 158,  95,  61, 215, 100, 145,  68, 150,  88,  67, 105,
       175, 160,  74, 135, 100,  67, 198, 180, 215, 100, 225, 155, 170,
        81,  85,  95,  80,  92,  70, 149,  84,  97,  52,  72,  85,  52,
        95,  71, 140, 100,  96, 150,  75, 107, 110,  75,  97, 133,  70,
        67, 112, 145, 115,  98,  70,  78, 230,  63,  76, 105,  95,  62,
       165, 165, 160, 190,  95, 180,  78, 120,  80,  75,  68,  67,  95,
       140, 110,  72, 150,  95,  54, 153, 130, 170,  86,  97,  90, 145,
        86,  79, 165,  83,  64,  92,  72, 140, 150,  96, 150,  80, 130,
       100, 125,  90,  94,  76,  90, 150,  97,  85,  81,  78,  46,  84,
        70, 153, 116, 100, 167,  88,  88,  88, 200, 125,  92, 110,  69,
        67,  90, 150,  90,  71, 105,  62,  88, 122,  65,  88,  90,  68,
       110,  88])

# %%
# Generate a 2-D histogram
plt.hist2d(hp,mpg, bins=(20,20), range=((40,235),(8,48)))

# Add a color bar to the histogram
plt.colorbar()

# Add labels, title, and display the plot
plt.xlabel('Horse power [hp]')
plt.ylabel('Miles per gallon [mpg]')
plt.title('hist2d() plot')
plt.show()

# %% [markdown]
# plt.hexbin()
#
# uses hexagonal bins. The underlying algorithm  constructs a hexagonal tesselation of a planar region and aggregates points inside hexagonal bins.
#
# - The optional gridsize argument (default 100) gives the number of hexagons across the x-direction used in the hexagonal tiling. If specified as a list or a tuple of length two, gridsize fixes the number of hexagon in the x- and y-directions respectively in the tiling.
# - The optional parameter extent=(xmin, xmax, ymin, ymax) specifies rectangular region covered by the hexagonal tiling. In that case, xmin and xmax are the respective lower and upper limits for the variables on the x-axis and ymin and ymax are the respective lower and upper limits for the variables on the y-axis.

# %%
# Generate a 2d histogram with hexagonal bins
plt.hexbin(hp, mpg, gridsize=(15,12), extent=(40,235,8,48))

           
# Add a color bar to the histogram
plt.colorbar()

# Add labels, title, and display the plot
plt.xlabel('Horse power [hp]')
plt.ylabel('Miles per gallon [mpg]')
plt.title('hexbin() plot')
plt.show()

# %% [markdown]
# ### Loading, examining images
#
# Color images such as photographs contain the intensity of the red, green and blue color channels.
#
# - To read an image from file, use plt.imread() by passing the path to a file, such as a PNG or JPG file.
# - The color image can be plotted as usual using plt.imshow().
# - The resulting image loaded is a NumPy array of three dimensions. The array typically has dimensions M×N×3, where M×N is the dimensions of the image. The third dimensions are referred to as color channels (typically red, green, and blue).
# - The color channels can be extracted by Numpy array slicing.

# %%
# Load the image into an array: img
img = plt.imread('480px-Astronaut-EVA.jpg')

# Print the shape of the image
print(img.shape)

# Display the image
plt.imshow(img)

# Hide the axes
plt.axis("off")
plt.show()
# Out:
# (480, 480, 3)

# %%
# Compute the sum of the red, green and blue channels: intensity
intensity = img.sum(axis=2)

# Print the shape of the intensity
print(intensity.shape)

# Display the intensity with a colormap of 'gray'
plt.imshow(intensity, cmap='gray')

# Add a colorbar
plt.colorbar()

# Hide the axes and show the figure
plt.axis('off')
plt.show()
# Out:
# (480, 480)

# %%
# Specify the extent and aspect ratio of the top left subplot
plt.subplot(2,2,1)
plt.title('extent=(-1,1,-1,1),\naspect=0.5') 
plt.xticks([-1,0,1])
plt.yticks([-1,0,1])
plt.imshow(img, extent=(-1,1,-1,1), aspect=0.5)

# Specify the extent and aspect ratio of the top right subplot
plt.subplot(2,2,2)
plt.title('extent=(-1,1,-1,1),\naspect=1')
plt.xticks([-1,0,1])
plt.yticks([-1,0,1])
plt.imshow(img, extent=(-1,1,-1,1), aspect=1)

# Specify the extent and aspect ratio of the bottom left subplot
plt.subplot(2,2,3)
plt.title('extent=(-1,1,-1,1),\naspect=2')
plt.xticks([-1,0,1])
plt.yticks([-1,0,1])
plt.imshow(img, extent=(-1,1,-1,1), aspect=2)

# Specify the extent and aspect ratio of the bottom right subplot
plt.subplot(2,2,4)
plt.title('extent=(-2,2,-1,1),\naspect=2')
plt.xticks([-2,-1,0,1,2])
plt.yticks([-1,0,1])
plt.imshow(img, extent=(-2,2,-1,1), aspect=2)

# Improve spacing and display the figure
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Seaborn

# %% [markdown]
# seaborn provides a convenient interface to generate complex and great-looking statistical plots:
#
# - sns.lmplot(): fit and visualize a simple linear regression between two variables
# - One difference between seaborn and regular matplotlib plotting is that you can pass pandas DataFrames directly to the plot and refer to each column by name. For example, if you were to plot the column 'price' vs the column 'area' from a DataFrame df, you could call sns.lmplot(x='area', y='price', data=df)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

auto = pd.read_csv('auto-mpg.csv')
sns.lmplot(x='weight', y='hp', data=auto)
plt.show()

# %%
sns.residplot(y='mpg', x='hp', data=auto, color='green')
plt.show()

# %%
plt.scatter(auto['weight'], auto['mpg'], label='data', color='red', marker='o')
sns.regplot(x='weight', y='mpg', data=auto, order=1, scatter=None, color='blue', label='order 1')
sns.regplot(x='weight', y='mpg', data=auto, order=2, scatter=None, color='green', label='order 2')
plt.legend(loc='upper right')
plt.show()

# %%
sns.residplot(y='weight', x='mpg', data=auto, color='gray', order=2)
plt.show()

# %%
sns.lmplot(x='weight', y='hp', data=auto, hue='origin', palette='Set1')
plt.show()

# %%
sns.lmplot(x='weight', y='hp', data=auto, row='origin', palette='Set1')
plt.show()

# %% [markdown]
# Regressions are useful to understand relationships between two continuous variables. Often we want to explore how the distribution of a single continuous variable is affected by a second categorical variable. Seaborn provides a variety of plot types to perform these types of comparisons between univariate distributions.
#
# **Strip Plot**
#
# The strip plot is one way of visualizing this kind of data. It plots the distribution of variables for each category as individual datapoints. For vertical strip plots (the default), distributions of continuous values are laid out parallel to the y-axis and the distinct categories are spaced out along the x-axis.

# %%
plt.subplot(2,1,1)
sns.stripplot(x='cyl', y='hp', data=auto)

plt.subplot(2,1,2)
sns.stripplot(x='cyl', y='hp', data=auto, jitter=True, size=3)

plt.tight_layout()
plt.show()

# %%
plt.subplot(2,1,1)
sns.swarmplot(x='cyl', y='hp', data=auto)

plt.subplot(2,1,2)
sns.swarmplot(y='cyl', x='hp', data=auto, orient='h', hue='origin')

plt.tight_layout()
plt.show()

# %%
plt.subplot(2,1,1)
sns.violinplot(x='cyl', y='hp', data=auto)

plt.subplot(2,1,2)
sns.violinplot(x='cyl', y='hp', data=auto, inner=None, color='lightgray')
sns.stripplot(x='cyl', y='hp', data=auto, jitter=True, size=1.5)

plt.tight_layout()
plt.show()

# %% [markdown]
# **Joint Distributions**
#
# There are numerous strategies to visualize how pairs of continuous random variables vary jointly. Regression and residual plots are one strategy. Another is to visualize a bivariate distribution.

# %%
sns.jointplot(x='hp', y='mpg', data=auto)
plt.show()

# %%
sns.jointplot(x='hp', y='mpg', data=auto, kind='hex')
plt.show()

# %%
sns.pairplot(auto)
plt.show()

# %%
sns.pairplot(auto, kind='reg', hue='origin')
plt.show()

# %% [markdown]
# ### Visualizing Time Series

# %%
import quandl

# %%
import datetime
 
# We will look at stock prices over the past year, starting at January 1, 2016
start = datetime.datetime(2016,1,1)
end = datetime.date.today()
 
# Let's get Apple stock data; Apple's ticker symbol is AAPL
# First argument is the series we want, second is the source ("yahoo" for Yahoo! Finance), 
# third is the start date, fourth is the end date
s = "AAPL"

aapl = quandl.get("WIKI/" + s, start_date=start, end_date=end)


import matplotlib.pyplot as plt

# Plot the aapl time series in blue
plt.plot(aapl['Adj. Close'], color='blue', label='NVDA')
# Specify the orientation of the xticks
plt.xticks(rotation=60)

# Display the plot
plt.show()

# %%
# Plot the series in the top subplot in blue
plt.subplot(2,1,1)
plt.xticks(rotation=45)
plt.title('AAPL: 2016 to 2018')
plt.plot(aapl['Adj. Close'], color='blue')

# Slice aapl from '2007' to '2008' inclusive: view
view = aapl['2018':'2018']

# Plot the sliced data in the bottom subplot in black
plt.subplot(2,1,2)
plt.xticks(rotation=45)
plt.title('AAPL: 2018')
plt.plot(view['Adj. Close'], color='black')
plt.tight_layout()
plt.show()

# %%
view = aapl['2018-01':'2018-04']

# Plot the entire series 
plt.plot(aapl['Adj. Close'])
plt.xticks(rotation=45)
plt.title('AAPL: 2016-20118')

# Specify the axes
plt.axes([0.2,0.55,0.25,0.25])

# Plot the sliced series in red using the current axes
plt.plot(view['Adj. Close'], color='red')
plt.xticks(rotation=45)
plt.title('2018/01-2018/04')
plt.show()

# %%
import datetime 
from pandas_datareader import data as pdr
import yfinance as yf

yf.pdr_override() # <== that's all it takes :-)

# download dataframe
data = pdr.get_data_yahoo("NVDA", 
                          start=datetime.datetime(2019, 1, 1), 
                          end=datetime.datetime(2019, 8, 21))
data.tail()
# Out:
# [*********************100%***********************]  1 of 1 downloaded
#               Open    High     Low   Close  Adj Close    Volume
# Date
# 2019-08-14  152.50  152.95  148.31  150.07     150.07  10497000
# 2019-08-15  150.83  151.63  147.39  148.77     148.77  11930000
# 2019-08-16  159.35  161.54  156.88  159.56     159.56  25199000
# 2019-08-19  164.12  171.42  163.47  170.78     170.78  20377800
# 2019-08-20  170.56  170.58  167.02  167.87     167.87  11588040

# %%
msft = yf.Ticker("NVDA")

# get stock info
print(msft.info)

# get historical market data
hist = msft.history(period="max")
print(hist.tail())

# show actions (dividends, splits)
print(msft.actions)

# show dividends
print(msft.dividends)

# show splits
print(msft.splits)

# show financials
print(msft.financials)

# show balance heet
print(msft.balance_sheet)

# show cashflow
print(msft.cashflow)

# show options expirations
print(msft.options)

# get option chain for specific expiration
#opt = msft.option_chain('YYYY-MM-DD')
# data available via: opt.calls, opt.puts
# Out:
# {'language': 'en-US', 'region': 'US', 'quoteType': 'EQUITY', 'quoteSourceName': 'Delayed Quote', 'currency': 'USD', 'shortName': 'NVIDIA Corporation', 'regularMarketPrice': 167.87, 'regularMarketTime': 1566331201, 'regularMarketChange': -2.9100037, 'regularMarketOpen': 170.56, 'regularMarketDayHigh': 170.58, 'regularMarketDayLow': 167.02, 'regularMarketVolume': 11588040, 'priceHint': 2, 'postMarketChangePercent': -0.08339751, 'postMarketTime': 1566345435, 'postMarketPrice': 167.73, 'postMarketChange': -0.13999939, 'regularMarketChangePercent': -1.7039487, 'regularMarketDayRange': '167.02 - 170.58', 'regularMarketPreviousClose': 170.78, 'bid': 0.0, 'ask': 0.0, 'bidSize': 8, 'askSize': 8, 'messageBoardId': 'finmb_32307', 'fullExchangeName': 'NasdaqGS', 'longName': 'NVIDIA Corporation', 'financialCurrency': 'USD', 'averageDailyVolume3Month': 10472048, 'averageDailyVolume10Day': 13963783, 'fiftyTwoWeekLowChange': 43.409996, 'fiftyTwoWeekLowChangePercent': 0.34878674, 'fiftyTwoWeekRange':
# ...

# %%
import yfinance as yf
stocks = "SPY NVDA AMD XLNX INTC FICO"
stocks = stocks.split()
data = yf.download(stocks, start="2019-01-01", end="2019-08-21")['Adj Close']
data.tail()
# Out:
# [*********************100%***********************]  6 of 6 downloaded
#               AMD    FICO   INTC    NVDA     SPY    XLNX
# Date
# 2019-08-14  30.24  326.93  45.87  150.07  283.90  102.98
# 2019-08-15  29.67  340.98  45.70  148.77  284.65  103.80
# 2019-08-16  31.18  350.12  46.50  159.56  288.85  105.46
# 2019-08-19  31.48  345.47  47.23  170.78  292.33  106.91
# 2019-08-20  30.72  346.40  46.60  167.87  290.02  105.10

# %%
plt.plot(data)
plt.xticks(rotation=45)
plt.grid("on")
stocks.sort()
plt.legend(stocks)

# %%
returns = pd.DataFrame()
for stock in data:
    if stock not in returns:
        returns[stock] = data[stock].pct_change()

returns = returns[1:]
returns.tail()
# Out:
#                  AMD      FICO      INTC      NVDA       SPY      XLNX
# Date
# 2019-08-14 -0.058237 -0.030830 -0.020709 -0.038321 -0.029568 -0.032416
# 2019-08-15 -0.018849  0.042976 -0.003706 -0.008663  0.002642  0.007963
# 2019-08-16  0.050893  0.026805  0.017505  0.072528  0.014755  0.015992
# 2019-08-19  0.009622 -0.013281  0.015699  0.070318  0.012048  0.013749
# 2019-08-20 -0.024142  0.002692 -0.013339 -0.017039 -0.007902 -0.016930

# %%
returns.describe()
# Out:
#               AMD        FICO        INTC        NVDA         SPY        XLNX
# count  159.000000  159.000000  159.000000  159.000000  159.000000  159.000000
# mean     0.003835    0.004085    0.000222    0.001731    0.001025    0.001697
# std      0.039576    0.017293    0.018181    0.028312    0.008650    0.029497
# min     -0.100974   -0.057474   -0.090014   -0.138235   -0.030073   -0.170774
# 25%     -0.018032   -0.005279   -0.008857   -0.015192   -0.002507   -0.009763
# 50%      0.001315    0.005066    0.000908    0.003205    0.001233    0.001115
# 75%      0.018454    0.014456    0.011142    0.016410    0.006225    0.015621
# max      0.199481    0.059909    0.061168    0.072528    0.033518    0.184300

# %%
returns.corr()['NVDA'].sort_values(ascending=False)
# Out:
# NVDA    1.000000
# SPY     0.705046
# AMD     0.657587
# INTC    0.610742
# XLNX    0.551229
# FICO    0.435613
# Name: NVDA, dtype: float64

# %%
from pandas.plotting import scatter_matrix
sm = scatter_matrix(returns, alpha=0.5)

# %% [markdown]
# ### Histogram Equalization of an Image

# %%
import matplotlib.pyplot as plt
import numpy as np

image = plt.imread('640px-Unequalized_Hawkes_Bay_NZ.jpg')

plt.subplot(2,2,1)
plt.title('Original image')
plt.axis('off')
plt.imshow(image, cmap='gray')

pixels = image.flatten() # into 1-dim pixels

plt.subplot(2,2,2)
plt.hist(pixels, bins=64, range=(0,256), density=True, color='red', alpha=0.4)

# Use plt.twinx() to overlay the CDF in the bottom subplot
plt.twinx()

# Display a cumulative histogram of the pixels
cdf, bins, patches = plt.hist(pixels, bins=64, range=(0,256),
               density=True, cumulative=True,
               color='blue', alpha=0.4)

new_pixels = np.interp(pixels, bins[:-1], cdf*255)

# Reshape new_pixels as a 2-D array: new_image
new_image = new_pixels.reshape(image.shape)
               
# Specify x-axis range, hide axes, add title and display plot
plt.xlim((0,256))
plt.title('PDF & CDF (original image)')


plt.subplot(2,2,3)
plt.title('Equalized image')
plt.axis('off')
plt.imshow(new_image, cmap='gray')

plt.subplot(2,2,4)
pdf = plt.hist(new_pixels, bins=64, range=(0,256), density=False,
               color='red', alpha=0.4)

# Use plt.twinx() to overlay the CDF in the bottom subplot
plt.twinx()
plt.xlim((0,256))


# Add title
plt.title('PDF & CDF (equalized image)')

# Generate a cumulative histogram of the new pixels
cdf = plt.hist(new_pixels, bins=64, range=(0,256),
               cumulative=True, density=True,
               color='blue', alpha=0.4)

plt.tight_layout()
plt.show()
